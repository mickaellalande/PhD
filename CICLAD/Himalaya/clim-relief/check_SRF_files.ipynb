# %%
# To reload external files automatically (ex: utils)
# %load_ext autoreload
# %autoreload 2

import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle # For rectangles
import proplot as plot # New plot library (https://proplot.readthedocs.io/en/latest/)
from scipy import stats # For linregress (trends)
import xesmf as xe # For regridding (https://xesmf.readthedocs.io/en/latest/)

import sys
sys.path.insert(1, '../../../') # to include my util file in previous directory
import utils as u # my personal functions
u.check_python_version()
u.check_virtual_memory()
# Out:
# 3.8.2 | packaged by conda-forge | (default, Feb 28 2020, 17:15:22)
# [GCC 7.3.0]
# Virtual memory usage - total: 252 GB / available: 217 GB / percent used: 13.8 %

# %% [markdown]
# # Check the surface variables first
# In particular the snow cover

# %%
path = '/data/mlalande/IGCM_OUT/LMDZOR/PROD/clim/clim-relief-def/SRF/Output/MO'

# %%
# !ls {path}
# Out:
# clim-relief-def_19800101_19801230_1M_sechiba_history.nc
# clim-relief-def_19810101_19811230_1M_sechiba_history.nc
# clim-relief-def_19820101_19821230_1M_sechiba_history.nc
# clim-relief-def_19830101_19831230_1M_sechiba_history.nc
# clim-relief-def_19840101_19841230_1M_sechiba_history.nc
# clim-relief-def_19850101_19851230_1M_sechiba_history.nc
# clim-relief-def_19860101_19861230_1M_sechiba_history.nc
# clim-relief-def_19870101_19871230_1M_sechiba_history.nc
# clim-relief-def_19880101_19881230_1M_sechiba_history.nc
# clim-relief-def_19890101_19891230_1M_sechiba_history.nc
# clim-relief-def_19900101_19901230_1M_sechiba_history.nc

# %%
# !ncdump -h {path}/clim-relief-def_19800101_19801230_1M_sechiba_history.nc | grep snow | grep long_name
# Out:
# 		snowlev:long_name = "Snow levels" ;
# 		snowf:long_name = "Snowfall rate" ;
# 		snow:long_name = "Snow mass" ;
# 		snowage:long_name = "Snow age on vegetated and bare soil area" ;
# 		snownobio:long_name = "Snow on nobio area" ;
# 		snownobioage:long_name = "Snow age on nobio area" ;
# 		snowmelt:long_name = "Snow melt" ;
# 		tot_melt:long_name = "Total melt from ice and snow" ;
# 		snowmelt_from_maxmass:long_name = "Snow melt above threshold" ;
# 		soilcap:long_name = "Surface heat capacity considering snow and soil surface" ;
# 		pkappa_snow:long_name = "Snow thermal conductivity" ;
# 		pcapa_snow:long_name = "Snow heat capacity" ;
# 		snowtemp:long_name = "snow temperature" ;
# 		snowtemp_weighted:long_name = "mean snow temperature weighted by snow density" ;
# 		snowliq:long_name = "Snow liquid content where land" ;
# 		snowdz:long_name = "Snow layer thickness in the snow fraction" ;
# 		snowrho:long_name = "Snow denisty" ;
# 		snowheat:long_name = "Snow heat content" ;
# 		snowgrain:long_name = "Snow grain size" ;
# 		snowdepth:long_name = "Total snow thickness (averaging over the entire land portion, including the snow-free fraction)" ;
# 		frac_snow:long_name = "Snow fraction on total area including snow on vegetated and bare soil and nobio area" ;
# 		snowliqtot:long_name = "Snow liquid content integrated over snow depth where land" ;
# 		snowage_glob:long_name = "Snow age on total area including snow on vegetated and bare soil and nobio area" ;

# %% [markdown]
# # Get the snow cover
# Attention calendrier 360d

# %%
latlim=(10,50)
lonlim=(60,110)

var_label = 'Snow cover extent [%]'
cmap='viridis'
levels=plot.arange(0,100,10)

# %%
ds = xr.open_mfdataset(path+'/*.nc', combine='by_coords')

# %%
ds.frac_snow[0].plot()

# %%
ds_HMA = ds.sel(lat=slice(50,10), lon=slice(60,110))

# %%
ds_HMA.frac_snow[0].plot()

# %% [markdown]
# # Let's target some 100% pixels
# http://localhost:7227/notebooks/notebooks/CICLAD/Himalaya/CMIP6_IPSL_bias/Snow%20cover.ipynb

# %%
ds_HMA.frac_snow
# Out:
# <xarray.DataArray 'frac_snow' (time_counter: 132, lat: 32, lon: 21)>
# dask.array<getitem, shape=(132, 32, 21), dtype=float32, chunksize=(12, 32, 21), chunktype=numpy.ndarray>
# Coordinates:
#   * lat            (lat) float32 49.43662 48.169014 ... 11.408451 10.140845
#   * lon            (lon) float32 60.0 62.5 65.0 67.5 ... 102.5 105.0 107.5 110.0
#     time_centered  (time_counter) object dask.array<chunksize=(12,), meta=np.ndarray>
#   * time_counter   (time_counter) object 1980-01-16 00:00:00 ... 1990-12-16 00:00:00
# Attributes:
#     long_name:           Snow fraction on total area including snow on vegeta...
#     units:               %
#     online_operation:    average
#     interval_operation:  900 s
#     interval_write:      1 month
#     cell_methods:        time: mean (interval: 900 s)

# %% [markdown]
# ## Choose pixels

# %%
ds_HMA.frac_snow[0].where(ds_HMA.frac_snow.sel(time_counter=slice('1985', '1990')).mean('time_counter') == 100, drop=True).plot()
# Out:
# /data/mlalande/miniconda3/envs/work/lib/python3.8/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /data/mlalande/miniconda3/envs/work/lib/python3.8/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
ds_HMA.frac_snow[0].where(ds_HMA.frac_snow.sel(time_counter=slice('1985', '1990')).mean('time_counter') == 100, drop=True)[-2, 4]
# Out:
# /data/mlalande/miniconda3/envs/work/lib/python3.8/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# <xarray.DataArray 'frac_snow' ()>
# dask.array<getitem, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     lat            float32 29.15493
#     lon            float32 82.5
#     time_centered  int64 dask.array<chunksize=(), meta=np.ndarray>
#     time_counter   object 1980-01-16 00:00:00
# Attributes:
#     long_name:           Snow fraction on total area including snow on vegeta...
#     units:               %
#     online_operation:    average
#     interval_operation:  900 s
#     interval_write:      1 month
#     cell_methods:        time: mean (interval: 900 s)

# %% [markdown]
# ## Plots them

# %%
# 3 100% points Karakoram, north-est, Himalaya
lat_100 = [35.492958, 29.15493, 29.15493, 38.028168]
lon_100 = [77.5, 82.5, 85.0, 97.5]
dx = 2.5
dy = 1.2676

# %%
def select_pixels(axs, lat, lon, dx, dy):
    for ax in axs:
        for i in range(len(lat)):
            ax.add_patch(
                Rectangle(
                    xy=[lon[i]-dx/2, lat[i]-dy/2], width=dx, height=dy, 
                    fill=False, color='C'+str(i), lw=4
                )
            )

# %%
f, axs = plot.subplots(ncols=1, nrows=1, proj='cyl', axwidth=5)

m = axs[0].pcolormesh(ds_HMA.frac_snow[0], cmap=cmap, levels=levels)
axs[0].format(title='')
f.colorbar(m, label=var_label)

select_pixels(axs, lat_100, lon_100, dx, dy)

axs.format(
    geogridlinewidth=0.5, geogridcolor='gray8', geogridalpha=0.5, labels=True, 
    coast=True, ocean=True, oceancolor='gray3', borders=True,
#     suptitle="",
    lonlines=10, latlines=10, abc=False, latlim=latlim, lonlim=lonlim
)

# f.save('.png')
# f.save('.pdf')

# %%
f, axs = plot.subplots(ncols=1, nrows=1, proj='cyl', axwidth=5)

m = axs[0].pcolormesh(clim_end, cmap=cmap, levels=levels)
axs[0].format(title='')
f.colorbar(m, label=var_label)

select_pixels(axs, lat_100, lon_100, dx, dy)

axs.format(
    geogridlinewidth=0.5, geogridcolor='gray8', geogridalpha=0.5, labels=True, 
    coast=True, ocean=True, oceancolor='gray3', borders=True,
#     suptitle="",
    lonlines=10, latlines=10, abc=False, latlim=latlim, lonlim=lonlim
)
# Out:
# /data/mlalande/miniconda3/envs/work/lib/python3.8/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %% [markdown]
# ## Let's plot the time series of these pixels

# %%
# !ncdump -h {path}/clim-relief-def_19800101_19801230_1M_sechiba_history.nc | grep snow | grep long_name
# Out:
# 		snowlev:long_name = "Snow levels" ;
# 		snowf:long_name = "Snowfall rate" ;
# 		snow:long_name = "Snow mass" ;
# 		snowage:long_name = "Snow age on vegetated and bare soil area" ;
# 		snownobio:long_name = "Snow on nobio area" ;
# 		snownobioage:long_name = "Snow age on nobio area" ;
# 		snowmelt:long_name = "Snow melt" ;
# 		tot_melt:long_name = "Total melt from ice and snow" ;
# 		snowmelt_from_maxmass:long_name = "Snow melt above threshold" ;
# 		soilcap:long_name = "Surface heat capacity considering snow and soil surface" ;
# 		pkappa_snow:long_name = "Snow thermal conductivity" ;
# 		pcapa_snow:long_name = "Snow heat capacity" ;
# 		snowtemp:long_name = "snow temperature" ;
# 		snowtemp_weighted:long_name = "mean snow temperature weighted by snow density" ;
# 		snowliq:long_name = "Snow liquid content where land" ;
# 		snowdz:long_name = "Snow layer thickness in the snow fraction" ;
# 		snowrho:long_name = "Snow denisty" ;
# 		snowheat:long_name = "Snow heat content" ;
# 		snowgrain:long_name = "Snow grain size" ;
# 		snowdepth:long_name = "Total snow thickness (averaging over the entire land portion, including the snow-free fraction)" ;
# 		frac_snow:long_name = "Snow fraction on total area including snow on vegetated and bare soil and nobio area" ;
# 		snowliqtot:long_name = "Snow liquid content integrated over snow depth where land" ;
# 		snowage_glob:long_name = "Snow age on total area including snow on vegetated and bare soil and nobio area" ;

# %%
ds_HMA
# Out:
# <xarray.Dataset>
# Dimensions:                (albtyp: 2, axis_nbounds: 2, lat: 32, lon: 21, nlut: 4, nobio: 1, snowlev: 3, soiltyp: 3, solay: 11, solth: 18, time_counter: 132, veget: 15)
# Coordinates:
#   * albtyp                 (albtyp) float32 1.0 2.0
#   * nlut                   (nlut) float32 1.0 2.0 3.0 4.0
#   * solth                  (solth) float32 0.00048875855 ... 65.56207
#   * veget                  (veget) float32 1.0 2.0 3.0 4.0 ... 13.0 14.0 15.0
#   * nobio                  (nobio) float32 1.0
#   * soiltyp                (soiltyp) float32 1.0 2.0 3.0
#   * snowlev                (snowlev) float32 1.0 2.0 3.0
#   * lat                    (lat) float32 49.43662 48.169014 ... 10.140845
#   * solay                  (solay) float32 1.0 2.0 3.0 4.0 ... 8.0 9.0 10.0 11.0
#   * lon                    (lon) float32 60.0 62.5 65.0 ... 105.0 107.5 110.0
#     time_centered          (time_counter) object dask.array<chunksize=(12,), meta=np.ndarray>
#   * time_counter           (time_counter) object 1980-01-16 00:00:00 ... 1990-12-16 00:00:00
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_centered_bounds   (time_counter, axis_nbounds) object dask.array<chunksize=(12, 2), meta=np.ndarray>
#     time_counter_bounds    (time_counter, axis_nbounds) object dask.array<chunksize=(12, 2), meta=np.ndarray>
#     Areas                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     Contfrac               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     evap                   (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     coastalflow            (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     riverflow              (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     coastalflow_cpl        (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     riverflow_cpl          (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     temp_sol               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     mrsow                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     ksat                   (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     rain                   (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     snowf                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     netrad                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     lai                    (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     reinf_slope            (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     soilindex              (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     basinmap               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     nbrivers               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     npp                    (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     WaterTableD            (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     TWS                    (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     subli                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     runoff                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     drainage               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     riversret              (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     hydrographs            (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     evapnu                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     evapnu_soil            (time_counter, soiltyp, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     drainage_soil          (time_counter, soiltyp, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     transpir_soil          (time_counter, soiltyp, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     runoff_soil            (time_counter, soiltyp, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     tair                   (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     qair                   (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     q2m                    (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     t2m                    (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     soilalb_bg             (time_counter, albtyp, lat, lon) float32 dask.array<chunksize=(12, 2, 32, 21), meta=np.ndarray>
#     alb_vis                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     alb_nir                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     soilalb_vis            (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     soilalb_nir            (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     vegalb_vis             (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     vegalb_nir             (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     z0h                    (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     z0m                    (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     roughheight            (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     transpir               (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     inter                  (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     DelSoilMoist_daily     (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     DelIntercept_daily     (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     DelSWE_daily           (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     delfastr_daily         (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     delslowr_daily         (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     delstreamr_daily       (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     dellakevol_daily       (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     delpondr_daily         (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     delfloodr_daily        (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     delstock_routing       (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     evapflo                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     undermcr               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     Qs_corr                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     Qs_corr2               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     Qsb_corr               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     Qforce                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     Qs_infilt              (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     Infilt                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     Qsb_corrnum            (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     tsol_max               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     tsol_min               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     fluxsens               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     fluxlat                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     snow                   (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     snowage                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     snownobio              (time_counter, nobio, lat, lon) float32 dask.array<chunksize=(12, 1, 32, 21), meta=np.ndarray>
#     snownobioage           (time_counter, nobio, lat, lon) float32 dask.array<chunksize=(12, 1, 32, 21), meta=np.ndarray>
#     vegetfrac              (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     maxvegetfrac           (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     tot_bare_soil          (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     nobiofrac              (time_counter, nobio, lat, lon) float32 dask.array<chunksize=(12, 1, 32, 21), meta=np.ndarray>
#     reinfiltration         (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     frac_bare              (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     soiltile               (time_counter, soiltyp, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     humtot                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     humtot_soil            (time_counter, soiltyp, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     qsintveg               (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     rstruct                (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     r_soil                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     gpp                    (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     gpp_ipcc2              (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     gppGrass               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     gppCrop                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     gppTree                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     nee                    (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     maint_resp             (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     hetero_resp            (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     growth_resp            (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     rh_ipcc2               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     rhGrass                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     rhCrop                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     rhTree                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     precisol               (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     throughfall            (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     drysoil_frac           (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     evapot                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     evapot_corr            (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     swnet                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     swdown                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     lwdown                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     lwnet                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     diffevap               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     temp_hydro             (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     snowmelt               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     tot_melt               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     snowmelt_from_maxmass  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     soilcap                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     TWBR                   (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     ptn                    (time_counter, solth, lat, lon) float32 dask.array<chunksize=(12, 18, 32, 21), meta=np.ndarray>
#     fastr                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     slowr                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     streamr                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     lakevol                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     lake_overflow          (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     mask_coast             (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     wbr_fast               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     wbr_slow               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     wbr_stream             (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     wbr_lake               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     pondr                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     swampmap               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     floodr                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     k_litt                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     beta                   (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     raero                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     cdrag                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     Wind                   (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     qsatt                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     vbeta1                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     vbeta4                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     vbeta5                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     gsmean                 (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     humrel                 (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     cimean                 (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     vbeta3                 (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     rveget                 (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     vbeta2                 (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     qsintmax               (time_counter, veget, lat, lon) float32 dask.array<chunksize=(12, 15, 32, 21), meta=np.ndarray>
#     dtes                   (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     tairmax                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     tasmax                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     tairmin                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     tasmin                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     clayfraction           (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     sandfraction           (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     siltfraction           (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     mrsos                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     mrso                   (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     mrros                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     mrro                   (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     prveg                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     evspsblveg             (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     evspsblsoi             (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     tran                   (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     vegFrac                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     treeFrac               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     treeFracNdlEvg         (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     treeFracBdlEvg         (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     treeFracNdlDcd         (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     treeFracBdlDcd         (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     grassFrac              (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     grassFracC3            (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     grassFracC4            (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     cropFrac               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     cropFracC3             (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     cropFracC4             (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     baresoilFrac           (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     residualFrac           (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     coszang                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     Psurf                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     Qb                     (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     CanopInt               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     LAImean                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     SoilSat                (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     mcr                    (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     nvg                    (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     alphavg                (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     RootDist               (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     SoilThick              (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     water2infilt           (time_counter, soiltyp, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     kk_moy                 (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     psi_moy                (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     profil_froz_hydro      (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     pkappa                 (time_counter, solth, lat, lon) float32 dask.array<chunksize=(12, 18, 32, 21), meta=np.ndarray>
#     pkappa_snow            (time_counter, snowlev, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     pcapa                  (time_counter, solth, lat, lon) float32 dask.array<chunksize=(12, 18, 32, 21), meta=np.ndarray>
#     pcapa_spec             (time_counter, solth, lat, lon) float32 dask.array<chunksize=(12, 18, 32, 21), meta=np.ndarray>
#     pcapa_snow             (time_counter, snowlev, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     snowtemp               (time_counter, snowlev, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     snowtemp_weighted      (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     snowliq                (time_counter, snowlev, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     snowdz                 (time_counter, snowlev, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     snowrho                (time_counter, snowlev, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     snowheat               (time_counter, snowlev, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     snowgrain              (time_counter, snowlev, lat, lon) float32 dask.array<chunksize=(12, 3, 32, 21), meta=np.ndarray>
#     snowdepth              (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     asoilcol               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     aalb_bg                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     atext                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     areftemp               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     alaimap                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     aslope                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     aveget                 (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     aveget5k               (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     achem_wrice            (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     achem_other            (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     achem_co2              (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     frac_snow              (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     snowliqtot             (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     SAlbedo                (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     snowage_glob           (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     lake_overflow_coast    (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     fracLut                (time_counter, nlut, lat, lon) float32 dask.array<chunksize=(12, 4, 32, 21), meta=np.ndarray>
#     nwdFraclut             (time_counter, nlut, lat, lon) float32 dask.array<chunksize=(12, 4, 32, 21), meta=np.ndarray>
#     mrsoLut                (time_counter, nlut, lat, lon) float32 dask.array<chunksize=(12, 4, 32, 21), meta=np.ndarray>
#     mrsosLut               (time_counter, nlut, lat, lon) float32 dask.array<chunksize=(12, 4, 32, 21), meta=np.ndarray>
#     mrroLut                (time_counter, nlut, lat, lon) float32 dask.array<chunksize=(12, 4, 32, 21), meta=np.ndarray>
#     gppLut                 (time_counter, nlut, lat, lon) float32 dask.array<chunksize=(12, 4, 32, 21), meta=np.ndarray>
#     cnc                    (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     mcfc                   (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     mcw                    (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     tmcs                   (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     tmcfc                  (time_counter, lat, lon) float32 dask.array<chunksize=(12, 32, 21), meta=np.ndarray>
#     wilt                   (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
#     fldcapacity            (time_counter, solay, lat, lon) float32 dask.array<chunksize=(12, 11, 32, 21), meta=np.ndarray>
# Attributes:
#     name:         sechiba_history
#     description:  Created by xios
#     title:        Created by xios
#     Conventions:  CF-1.6
#     timeStamp:    2020-May-05 07:21:28 GMT
#     uuid:         cae362eb-8c19-4504-a4f0-46788c90198c
#     LongName:     LMDZOR configuration
#     history:      Tue May  5 10:27:47 2020: ncrcat -C --buffer_size 838860800...
#     NCO:          netCDF Operators version 4.8.1 (Homepage = http://nco.sf.ne...

# %%
ds_HMA.DelSWE_daily
# Out:
# <xarray.DataArray 'DelSWE_daily' (time_counter: 132, lat: 32, lon: 21)>
# dask.array<getitem, shape=(132, 32, 21), dtype=float32, chunksize=(12, 32, 21), chunktype=numpy.ndarray>
# Coordinates:
#   * lat            (lat) float32 49.43662 48.169014 ... 11.408451 10.140845
#   * lon            (lon) float32 60.0 62.5 65.0 67.5 ... 102.5 105.0 107.5 110.0
#     time_centered  (time_counter) object dask.array<chunksize=(12,), meta=np.ndarray>
#   * time_counter   (time_counter) object 1980-01-16 00:00:00 ... 1990-12-16 00:00:00
# Attributes:
#     long_name:           Change in Snow Water Equivalent accumulated over eac...
#     units:               kg/m^2/d
#     online_operation:    average
#     interval_operation:  1 d
#     interval_write:      1 month
#     cell_methods:        time: mean (interval: 1 d)

# %%
n = len(lat_100)
variables = [
    'frac_snow','snow', 'snowage_glob', 'snowmelt', 'tot_melt', 'snowmelt_from_maxmass',
    'snowtemp_weighted', 'snowdepth', 'rain', 'snowf',
    't2m', 'subli'
]

f, axs = plot.subplots(ncols=4, nrows=len(variables)//4+1, sharey=0)

hs = []
for k, variable in enumerate(variables):
    for i in range(n):
        ds_HMA[variable].sel(lat=lat_100[i], lon=lon_100[i], time_counter=slice('1980', '1984')).plot(ax=axs[k], label='test')
        axs[k].format(title=variable)

# %%
n = len(lat_100)

f, axs = plot.subplots(ncols=n, nrows=1)

for i in range(n):
    ds_HMA.frac_snow.sel(lat=lat_100[i], lon=lon_100[i], time_counter=slice('1980', '1984')).plot(ax=axs[i])
    
axs.format(ylim=(0,105))

# %%
f, axs = plot.subplots(ncols=n, nrows=1)
for i in range(n):
    ds_HMA.snow.sel(lat=lat_100[i], lon=lon_100[i], time_counter=slice('1980', '1984')).plot(ax=axs[i])

# %%
f, axs = plot.subplots(ncols=n, nrows=1)
for i in range(n):
    ds_HMA.snowtemp.sel(snowlev=3.0, lat=lat_100[i], lon=lon_100[i], time_counter=slice('1980', '1984')).plot(ax=axs[i])

# %%
f, axs = plot.subplots(ncols=n, nrows=1)
for i in range(n):
    ds_HMA.rain.sel(lat=lat_100[i], lon=lon_100[i], time_counter=slice('1980', '1984')).plot(ax=axs[i])

# %%
f, axs = plot.subplots(ncols=n, nrows=1)
for i in range(n):
    ds_HMA.snowage.sel(lat=lat_100[i], lon=lon_100[i], time_counter=slice('1980', '1984')).plot(ax=axs[i])

# %%
f, axs = plot.subplots(ncols=n, nrows=1)
for i in range(n):
    ds_HMA.snownobio.sel(lat=lat_100[i], lon=lon_100[i], time_counter=slice('1980', '1984')).plot(ax=axs[i])
