# %%
import xarray as xr
import proplot as plot

# %%
path = '/gpfsscratch/rech/goe/ufz23bm/IGCM_OUT/LMDZOR/TEST/amip/Amip-144x142x79-zoomx2-himalaya-test/ATM/Output/DA/'

# %%
ds = xr.open_dataset(path+'Amip-144x142x79-zoomx2-himalaya-test_19800101_19800101_1D_histday.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:               (axis_nbounds: 2, lat: 143, lon: 144, presnivs: 79, time_counter: 1)
# Coordinates:
#   * lat                   (lat) float32 90.0 88.50914 ... -88.49235 -90.0
#   * lon                   (lon) float32 -178.43634 -175.47523 ... 178.61938
#   * presnivs              (presnivs) float32 101202.11 100942.43 ... 1.4834349
#     time_centered         (time_counter) datetime64[ns] ...
#   * time_counter          (time_counter) datetime64[ns] 1980-01-01T12:00:00
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_centered_bounds  (time_counter, axis_nbounds) datetime64[ns] ...
#     time_counter_bounds   (time_counter, axis_nbounds) datetime64[ns] ...
#     phis                  (time_counter, lat, lon) float32 ...
#     aire                  (lat, lon) float32 ...
#     contfracATM           (lat, lon) float32 ...
#     contfracOR            (time_counter, lat, lon) float32 ...
#     flat                  (time_counter, lat, lon) float32 ...
#     slp                   (time_counter, lat, lon) float32 ...
#     sza                   (time_counter, lat, lon) float32 ...
#     ptstar                (time_counter, lat, lon) float32 ...
#     pt0                   (time_counter, lat, lon) float32 ...
#     tsol                  (time_counter, lat, lon) float32 ...
#     t2m                   (time_counter, lat, lon) float32 ...
#     t2m_min               (time_counter, lat, lon) float32 ...
#     t2m_max               (time_counter, lat, lon) float32 ...
#     gusts                 (time_counter, lat, lon) float32 ...
#     wind10m               (time_counter, lat, lon) float32 ...
#     wind10max             (time_counter, lat, lon) float32 ...
#     sicf                  (time_counter, lat, lon) float32 ...
#     q2m                   (time_counter, lat, lon) float32 ...
#     ustar                 (time_counter, lat, lon) float32 ...
#     u10m                  (time_counter, lat, lon) float32 ...
#     v10m                  (time_counter, lat, lon) float32 ...
#     psol                  (time_counter, lat, lon) float32 ...
#     precip                (time_counter, lat, lon) float32 ...
#     rain_fall             (time_counter, lat, lon) float32 ...
#     rain_con              (time_counter, lat, lon) float32 ...
#     plul                  (time_counter, lat, lon) float32 ...
#     plun                  (time_counter, lat, lon) float32 ...
#     pluc                  (time_counter, lat, lon) float32 ...
#     snow                  (time_counter, lat, lon) float32 ...
#     evap                  (time_counter, lat, lon) float32 ...
#     tops                  (time_counter, lat, lon) float32 ...
#     topl                  (time_counter, lat, lon) float32 ...
#     sols                  (time_counter, lat, lon) float32 ...
#     soll                  (time_counter, lat, lon) float32 ...
#     SWdnSFC               (time_counter, lat, lon) float32 ...
#     bils                  (time_counter, lat, lon) float32 ...
#     bils_tke              (time_counter, lat, lon) float32 ...
#     bils_diss             (time_counter, lat, lon) float32 ...
#     bils_ec               (time_counter, lat, lon) float32 ...
#     bils_kinetic          (time_counter, lat, lon) float32 ...
#     bils_enthalp          (time_counter, lat, lon) float32 ...
#     bils_latent           (time_counter, lat, lon) float32 ...
#     sens                  (time_counter, lat, lon) float32 ...
#     fder                  (time_counter, lat, lon) float32 ...
#     cldl                  (time_counter, lat, lon) float32 ...
#     cldm                  (time_counter, lat, lon) float32 ...
#     cldh                  (time_counter, lat, lon) float32 ...
#     cldt                  (time_counter, lat, lon) float32 ...
#     cldq                  (time_counter, lat, lon) float32 ...
#     prw                   (time_counter, lat, lon) float32 ...
#     prlw                  (time_counter, lat, lon) float32 ...
#     prsw                  (time_counter, lat, lon) float32 ...
#     slab_bils_oce         (time_counter, lat, lon) float32 ...
#     ale_bl                (time_counter, lat, lon) float32 ...
#     alp_bl                (time_counter, lat, lon) float32 ...
#     ale_wk                (time_counter, lat, lon) float32 ...
#     alp_wk                (time_counter, lat, lon) float32 ...
#     ale                   (time_counter, lat, lon) float32 ...
#     alp                   (time_counter, lat, lon) float32 ...
#     cin                   (time_counter, lat, lon) float32 ...
#     wape                  (time_counter, lat, lon) float32 ...
#     n2                    (time_counter, lat, lon) float32 ...
#     s2                    (time_counter, lat, lon) float32 ...
#     proba_notrig          (time_counter, lat, lon) float32 ...
#     random_notrig         (time_counter, lat, lon) float32 ...
#     ale_bl_stat           (time_counter, lat, lon) float32 ...
#     ale_bl_trig           (time_counter, lat, lon) float32 ...
#     alp_bl_det            (time_counter, lat, lon) float32 ...
#     alp_bl_fluct_m        (time_counter, lat, lon) float32 ...
#     alp_bl_fluct_tke      (time_counter, lat, lon) float32 ...
#     alp_bl_conv           (time_counter, lat, lon) float32 ...
#     alp_bl_stat           (time_counter, lat, lon) float32 ...
#     weakinv               (time_counter, lat, lon) float32 ...
#     dthmin                (time_counter, lat, lon) float32 ...
#     snowl                 (time_counter, lat, lon) float32 ...
#     cape_max              (time_counter, lat, lon) float32 ...
#     solldown              (time_counter, lat, lon) float32 ...
#     topswad               (time_counter, lat, lon) float32 ...
#     topswad0              (time_counter, lat, lon) float32 ...
#     toplwad               (time_counter, lat, lon) float32 ...
#     toplwad0              (time_counter, lat, lon) float32 ...
#     od550_STRAT           (time_counter, lat, lon) float32 ...
#     wdtrainA              (time_counter, presnivs, lat, lon) float32 ...
#     wdtrainM              (time_counter, presnivs, lat, lon) float32 ...
#     stratomask            (time_counter, presnivs, lat, lon) float32 ...
#     cool_volc             (time_counter, presnivs, lat, lon) float32 ...
#     heat_volc             (time_counter, presnivs, lat, lon) float32 ...
# Attributes:
#     name:         histday
#     description:  Created by xios
#     title:        Created by xios
#     Conventions:  CF-1.6
#     timeStamp:    2020-Feb-03 14:40:38 GMT
#     uuid:         a84bc50d-2a14-46f5-9595-de9b5abaabc3
#     LongName:     LMDZOR configuration

# %%
ds.aire.plot()

# %%
# %matplotlib notebook
ds.t2m.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib inline
f, axs = plot.subplots(proj='cyl', axwidth=6)

axs.format(coast=True, labels=True)

axs.pcolormesh(ds.t2m[0]-273.15, cmap='coolwarm', norm='midpoint', colorbar='r', globe=True, levels=256)

# %%
# %matplotlib inline
f, axs = plot.subplots(proj='cyl', axwidth=6)

axs.format(coast=True, labels=True, lonlim=(50,100), latlim=(0,40), lonlines=5, latlines=5)

axs.pcolormesh(ds.t2m[0]-273.15, cmap='coolwarm', norm='midpoint', colorbar='r', globe=True, levels=256)
