# %% [markdown]
# # Adding cyclic point feature #82
# https://github.com/lukelbd/proplot/issues/82#issuecomment-739767805

# %%
import xarray as xr

diff_new = xr.open_dataarray('data/ens_avg_snow.nc')

# %%
import proplot as plot

f, axs = plot.subplots(proj='cyl', width=8)
m = axs[0].contourf(ens_avg_snow, cmap='ice', globe=True)
f.colorbar(m, loc='b', shrink=0.7, label='Sea-ice thickness (m)')

axs.format(labels=True, coast=True)
# Out:
# /home/lalandmi/miniconda3/envs/phd_v3/lib/python3.8/site-packages/xarray/core/nanops.py:142: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)

# %%
plot.__version__
# Out:
# '0.6.4'
