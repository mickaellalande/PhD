# %% [markdown]
# https://github.com/pydata/xarray/issues/2436
#
# conda env: xarray_v0.16.0

# %%
import xarray as xr
import glob

# %%
ds = xr.tutorial.open_dataset('air_temperature')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 ...
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
ds.time.encoding
# Out:
# {'source': '/home/lalandmi/.xarray_tutorial_data/air_temperature.nc',
#  'original_shape': (2920,),
#  'dtype': dtype('float32'),
#  'units': 'hours since 1800-01-01',
#  'calendar': 'standard'}

# %%
# ds.sel(time='2013').to_netcdf('tutorial_air_temperature_2013.nc')
# ds.sel(time='2014').to_netcdf('tutorial_air_temperature_2014.nc')

# %%
ds_mf = xr.open_mfdataset('tutorial_air_temperature_*.nc', combine='by_coords')
ds_mf
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 dask.array<concatenate, shape=(2920, 25...
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
ds_mf.time.encoding
# Out:
# {}

# %% [markdown]
# https://github.com/pydata/xarray/issues/2436

# %%
paths = sorted(glob.glob("tutorial_air_temperature_*.nc")) 
paths
# Out:
# ['tutorial_air_temperature_2013.nc', 'tutorial_air_temperature_2014.nc']

# %%
ds = xr.open_mfdataset(paths, combine="by_coords", attrs_file=paths[0])
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 dask.array<concatenate, shape=(2920, 25...
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
ds.time.encoding
# Out:
# {}

# %%
xr.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.8.4 | packaged by conda-forge | (default, Jul 17 2020, 15:16:46)
# [GCC 7.5.0]
# python-bits: 64
# OS: Linux
# OS-release: 4.19.0-9-amd64
# machine: x86_64
# processor:
# byteorder: little
# LC_ALL: None
# LANG: fr_FR.UTF-8
# LOCALE: fr_FR.UTF-8
# libhdf5: 1.10.6
# libnetcdf: 4.7.4
#
# xarray: 0.16.0
# pandas: 1.0.5
# numpy: 1.19.0
# scipy: None
# netCDF4: 1.5.3
# pydap: None
# h5netcdf: None
# h5py: None
# Nio: None
# zarr: None
# cftime: 1.2.1
# nc_time_axis: None
# PseudoNetCDF: None
# rasterio: None
# cfgrib: None
# iris: None
# bottleneck: None
# dask: 2.21.0
# distributed: 2.21.0
# matplotlib: None
# cartopy: None
# seaborn: None
# numbagg: None
# pint: None
# setuptools: 49.2.0.post20200712
# pip: 20.1.1
# conda: None
# pytest: None
# IPython: 7.16.1
# sphinx: None
# /home/lalandmi/miniconda3/envs/xarray_v0.16.0/lib/python3.8/site-packages/setuptools/distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(

# %%
import cftime
import numpy as np

# %%
units = 'days since 2000-02-25' 
times = cftime.num2date(np.arange(7), units=units, calendar='365_day') 
times
# Out:
# array([cftime.DatetimeNoLeap(2000, 2, 25, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 2, 26, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 2, 27, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 2, 28, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 3, 1, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 3, 2, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 3, 3, 0, 0, 0, 0)], dtype=object)

# %%
x = 1
ds = xr.DataArray( 
    np.arange(x, 7 + x).reshape(7, 1), 
    coords={"time": times, "x": [x]}, 
    dims=['time', "x"], 
    name='a', 
).to_dataset() 
# ds.to_netcdf(f'data-noleap{x}.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 7, x: 1)
# Coordinates:
#   * time     (time) object 2000-02-25 00:00:00 ... 2000-03-03 00:00:00
#   * x        (x) int64 1
# Data variables:
#     a        (time, x) int64 1 2 3 4 5 6 7

# %%
ds.time
# Out:
# <xarray.DataArray 'time' (time: 7)>
# array([cftime.DatetimeNoLeap(2000, 2, 25, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 2, 26, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 2, 27, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 2, 28, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 3, 1, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 3, 2, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 3, 3, 0, 0, 0, 0)], dtype=object)
# Coordinates:
#   * time     (time) object 2000-02-25 00:00:00 ... 2000-03-03 00:00:00

# %%
for x in range(5): 
    ds = xr.DataArray( 
        np.arange(x, 7 + x).reshape(7, 1), 
        coords={"time": times, "x": [x]}, 
        dims=['time', "x"], 
        name='a', 
    ).to_dataset() 
    ds.to_netcdf(f'data-noleap{x}.nc') 
paths = sorted(glob.glob("data-noleap*.nc")) 
with xr.open_mfdataset(paths, combine="by_coords") as ds: 
    print(ds.time.encoding)
# Out:
# {'zlib': False, 'shuffle': False, 'complevel': 0, 'fletcher32': False, 'contiguous': True, 'chunksizes': None, 'source': '/home/lalandmi/Dropbox/Thèse/notebooks/bugs/xarray/data-noleap0.nc', 'original_shape': (7,), 'dtype': dtype('int64'), 'units': 'days since 2000-02-25 00:00:00.000000', 'calendar': 'noleap'}

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 7, x: 5)
# Coordinates:
#   * time     (time) object 2000-02-25 00:00:00 ... 2000-03-03 00:00:00
#   * x        (x) int64 0 1 2 3 4
# Data variables:
#     a        (time, x) int64 dask.array<concatenate, shape=(7, 5), dtype=int6...

# %%
ds.time
# Out:
# <xarray.DataArray 'time' (time: 7)>
# array([cftime.DatetimeNoLeap(2000, 2, 25, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 2, 26, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 2, 27, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 2, 28, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 3, 1, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 3, 2, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2000, 3, 3, 0, 0, 0, 0)], dtype=object)
# Coordinates:
#   * time     (time) object 2000-02-25 00:00:00 ... 2000-03-03 00:00:00
