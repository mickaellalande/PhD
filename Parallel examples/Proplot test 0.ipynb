# %%
import xarray as xr
import proplot as plot

# %%
da = xr.tutorial.open_dataset('air_temperature').isel(time=0).air
da
# Out:
# <xarray.DataArray 'air' (lat: 25, lon: 53)>
# array([[241.2    , 242.5    , 243.5    , ..., 232.79999, 235.5    , 238.59999],
#        [243.79999, 244.5    , 244.7    , ..., 232.79999, 235.29999, 239.29999],
#        [250.     , 249.79999, 248.89   , ..., 233.2    , 236.39   , 241.7    ],
#        ...,
#        [296.6    , 296.19998, 296.4    , ..., 295.4    , 295.1    , 294.69998],
#        [295.9    , 296.19998, 296.79   , ..., 295.9    , 295.9    , 295.19998],
#        [296.29   , 296.79   , 297.1    , ..., 296.9    , 296.79   , 296.6    ]],
#       dtype=float32)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#     time     datetime64[ns] 2013-01-01
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %%
f, axs = plot.subplots(proj='cyl', axwidth=3)

cmap='ColdHot'
levels=plot.arange(-10,10, 1)

m = axs.pcolormesh(((da-273.15)*0.01), cmap=cmap, levels=levels, colorbar='r')

axs.format(labels=True, coast=True, borders=True,
    latlim=(da.lat.min(), da.lat.max()), lonlim=(da.lon.min(), da.lon.max())
)

f.save('temp_1.png')

# %%
f, axs = plot.subplots(proj='cyl', axwidth=3)

cmap='ColdHot'
levels=plot.arange(-2, 2, 0.1)

m = axs.pcolormesh(((da-273.15)*0.01), cmap=cmap, levels=levels, colorbar='r')

axs.format(labels=True, coast=True, borders=True,
    latlim=(da.lat.min(), da.lat.max()), lonlim=(da.lon.min(), da.lon.max())
)

f.save('temp_2.png')

# %%
f, axs = plot.subplots(proj='cyl', axwidth=3)

cmap='ColdHot'
levels=plot.arange(-1, 1, 0.1)

m = axs.pcolormesh(((da-273.15)*0.01), cmap=cmap, levels=levels, colorbar='r')

axs.format(labels=True, coast=True, borders=True,
    latlim=(da.lat.min(), da.lat.max()), lonlim=(da.lon.min(), da.lon.max())
)
# Out:
# /home/mlalande/miniconda3/lib/python3.7/site-packages/proplot/axistools.py:470: RuntimeWarning: invalid value encountered in log10
#   abs(np.log10(x) // 1), MAX_DIGITS)).format(x)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-144f0fd571aa> in <module>
#       4 levels=plot.arange(-1, 1, 0.1)
#       5
# ----> 6 m = axs.pcolormesh(((da-273.15)*0.01), cmap=cmap, levels=levels, colorbar='r')
#       7
#       8 axs.format(labels=True, coast=True, borders=True,
#
# ~/miniconda3/lib/python3.7/site-packages/proplot/subplots.py in _iterator(*args, **kwargs)
#     223                 ret = []
#     224                 for func in objs:
# --> 225                     ret.append(func(*args, **kwargs))
#     226                 ret = (*ret,)
#     227                 if len(self) == 1:
#
# ~/miniconda3/lib/python3.7/site-packages/proplot/wrappers.py in _wrapper(self, *args, **kwargs)
#    3018         @functools.wraps(func)
#    3019         def _wrapper(self, *args, **kwargs):
# -> 3020             return driver(self, func, *args, **kwargs)
#    3021         name = func.__name__
#    3022         if name not in proplot_methods:
#
# ~/miniconda3/lib/python3.7/site-packages/proplot/wrappers.py in default_transform(self, func, transform, *args, **kwargs)
#     116     if transform is None:
#     117         transform = PlateCarree()
# --> 118     result = func(self, *args, transform=transform, **kwargs)
#     119     return result
#     120
#
# ~/miniconda3/lib/python3.7/site-packages/proplot/wrappers.py in _wrapper(self, *args, **kwargs)
#    3018         @functools.wraps(func)
#    3019         def _wrapper(self, *args, **kwargs):
# -> 3020             return driver(self, func, *args, **kwargs)
#    3021         name = func.__name__
#    3022         if name not in proplot_methods:
#
# ~/miniconda3/lib/python3.7/site-packages/proplot/wrappers.py in standardize_2d(self, func, order, globe, *args, **kwargs)
#     664     colorbar_kw = kwargs.pop('colorbar_kw', None) or {}
#     665     colorbar_kw.setdefault('label', colorbar_label)
# --> 666     return func(self, x, y, *Zs, colorbar_kw=colorbar_kw, **kwargs)
#     667
#     668
#
# ~/miniconda3/lib/python3.7/site-packages/proplot/wrappers.py in _wrapper(self, *args, **kwargs)
#    3018         @functools.wraps(func)
#    3019         def _wrapper(self, *args, **kwargs):
# -> 3020             return driver(self, func, *args, **kwargs)
#    3021         name = func.__name__
#    3022         if name not in proplot_methods:
#
# ~/miniconda3/lib/python3.7/site-packages/proplot/wrappers.py in cmap_changer(self, func, cmap, cmap_kw, extend, norm, norm_kw, N, levels, values, centers, vmin, vmax, locator, symmetric, locator_kw, edgefix, labels, labels_kw, fmt, precision, colorbar, colorbar_kw, lw, linewidth, linewidths, ls, linestyle, linestyles, color, colors, edgecolor, edgecolors, *args, **kwargs)
#    2158         if loc != 'fill':
#    2159             colorbar_kw.setdefault('loc', loc)
# -> 2160         self.colorbar(obj, **colorbar_kw)
#    2161     return obj
#    2162
#
# ~/miniconda3/lib/python3.7/site-packages/proplot/axes.py in colorbar(self, loc, pad, length, width, space, frame, frameon, alpha, linewidth, edgecolor, facecolor, *args, **kwargs)
#     935         if loc in ('left', 'right', 'top', 'bottom'):
#     936             ax = self.panel_axes(loc, width=width, space=space, filled=True)
# --> 937             return ax.colorbar(loc='_fill', *args, length=length, **kwargs)
#     938
#     939         # Filled colorbar
#
# ~/miniconda3/lib/python3.7/site-packages/proplot/axes.py in colorbar(self, loc, pad, length, width, space, frame, frameon, alpha, linewidth, edgecolor, facecolor, *args, **kwargs)
#    1093
#    1094         # Generate colorbar
# -> 1095         return colorbar_wrapper(ax, *args, **kwargs)
#    1096
#    1097     def legend(self, *args, loc=None, width=None, space=None, **kwargs):
#
# ~/miniconda3/lib/python3.7/site-packages/proplot/wrappers.py in colorbar_wrapper(self, mappable, values, extend, extendsize, title, label, grid, tickminor, tickloc, ticklocation, locator, ticks, maxn, maxn_minor, minorlocator, minorticks, locator_kw, minorlocator_kw, formatter, ticklabels, formatter_kw, norm, norm_kw, orientation, edgecolor, linewidth, labelsize, labelweight, labelcolor, ticklabelsize, ticklabelweight, ticklabelcolor, **kwargs)
#    2876     except Exception as err:
#    2877         self.figure._locked = True
# -> 2878         raise err
#    2879     axis = self.xaxis if orientation == 'horizontal' else self.yaxis
#    2880
#
# ~/miniconda3/lib/python3.7/site-packages/proplot/wrappers.py in colorbar_wrapper(self, mappable, values, extend, extendsize, title, label, grid, tickminor, tickloc, ticklocation, locator, ticks, maxn, maxn_minor, minorlocator, minorticks, locator_kw, minorlocator_kw, formatter, ticklabels, formatter_kw, norm, norm_kw, orientation, edgecolor, linewidth, labelsize, labelweight, labelcolor, ticklabelsize, ticklabelweight, ticklabelcolor, **kwargs)
#    2873     try:
#    2874         self.figure._locked = False
# -> 2875         cb = self.figure.colorbar(mappable, **kwargs)
#    2876     except Exception as err:
#    2877         self.figure._locked = True
#
# ~/miniconda3/lib/python3.7/site-packages/proplot/subplots.py in colorbar(self, loc, width, space, row, col, rows, cols, span, *args, **kwargs)
#    1713         # Fill this axes
#    1714         if cax is not None:
# -> 1715             return super().colorbar(*args, cax=cax, **kwargs)
#    1716         # Generate axes panel
#    1717         elif ax is not None:
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2213                              'panchor']
#    2214         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2215         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2216
#    2217         self.sca(current_ax)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1638         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1639     else:
# -> 1640         cb = Colorbar(cax, mappable, **kwargs)
#    1641
#    1642     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#    1181                 kw['alpha'] = mappable.get_alpha()
#    1182
# -> 1183             ColorbarBase.__init__(self, ax, **kw)
#    1184
#    1185     def on_mappable_changed(self, mappable):
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/colorbar.py in __init__(self, ax, cmap, norm, alpha, values, boundaries, orientation, ticklocation, extend, spacing, ticks, format, drawedges, filled, extendfrac, extendrect, label)
#     458         else:
#     459             self.formatter = format  # Assume it is a Formatter or None
# --> 460         self.draw_all()
#     461
#     462     def _extend_lower(self):
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/colorbar.py in draw_all(self)
#     491         C = self._values[:, np.newaxis]
#     492         self.config_axis()
# --> 493         self._config_axes(X, Y)
#     494         if self.filled:
#     495             self._add_solids(X, Y, C)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/colorbar.py in _config_axes(self, X, Y)
#     725         ax.add_artist(self.patch)
#     726
# --> 727         self.update_ticks()
#     728
#     729     def _set_label(self):
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/colorbar.py in update_ticks(self)
#     612         else:
#     613             _log.debug('Using fixed locator on colorbar')
# --> 614             ticks, ticklabels, offset_string = self._ticker(locator, formatter)
#     615             long_axis.set_ticks(ticks)
#     616             long_axis.set_ticklabels(ticklabels)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/colorbar.py in _ticker(self, locator, formatter)
#     857         self._manual_tick_data_values = b
#     858         ticks = self._locate(b)
# --> 859         ticklabels = formatter.format_ticks(b)
#     860         offset_string = formatter.get_offset()
#     861         return ticks, ticklabels, offset_string
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/ticker.py in format_ticks(self, values)
#     257         """Return the tick labels for all the ticks at once."""
#     258         self.set_locs(values)
# --> 259         return [self(value, i) for i, value in enumerate(values)]
#     260
#     261     def format_data(self, value):
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/ticker.py in <listcomp>(.0)
#     257         """Return the tick labels for all the ticks at once."""
#     258         self.set_locs(values)
# --> 259         return [self(value, i) for i, value in enumerate(values)]
#     260
#     261     def format_data(self, value):
#
# ~/miniconda3/lib/python3.7/site-packages/proplot/axistools.py in __call__(self, x, pos)
#     468                 # Hard limit of MAX_DIGITS sigfigs
#     469                 string = ('{:.%df}' % min(
# --> 470                     abs(np.log10(x) // 1), MAX_DIGITS)).format(x)
#     471                 continue
#     472             break
#
# ValueError: cannot convert float NaN to integer
