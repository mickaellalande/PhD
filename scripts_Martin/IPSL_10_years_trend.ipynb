# %%
# We check the CMIP6 snow data availability
from climaf.api import *
# Out:
# ('LC debug :', False)
# CliMAF install => /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_1.2.12
# python => /prodigfs/ipslfs/dods/jservon/miniconda/envs/analyse_env_2.7/bin/python
# ---
# Required softwares to run CliMAF => you are using the following versions/installations:
# CliMAF version = 1.2.12
# ncl 6.6.2 => /prodigfs/ipslfs/dods/jservon/miniconda/envs/analyse_env_2.7/bin/ncl
# cdo 1.9.6 => /opt/nco/1.9/bin/cdo
# nco (ncks) 4.5.2 => /opt/nco-4.5.2/bin/ncks
# ncdump fichier => /prodigfs/ipslfs/dods/jservon/miniconda/envs/analyse_env_2.7/bin/ncdump
# ---
# Cache directory set to : /data/mlalande/climafcache (use $CLIMAF_CACHE if set)
# Cache directory for remote data set to : /data/mlalande/climafcache/remote_data (use $CLIMAF_REMOTE_CACHE if set)
# warning  : Binary cdftools not found. Some operators won't work
# Available macros read from ~/.climaf.macros are : []

# %%
first_year=2005
last_year=2014
period_extract=str(first_year)+'-'+str(last_year)
figure_type='.png'
figure_type2='.ps'
period_extract
# Out:
# '2005-2014'

# %%
# IPSL 31 members, that should be done only for Northern hemisphere
req_snow = ds(project='CMIP6', model='IPSL-CM6A-LR',
              variable='snc', table="LImon",frequency='monthly',realization='*',
               period=period_extract,experiment='historical',domain=[25,90,-180,180])

# %%
req_snow.explore('choices')
# Out:
# {'grid': 'gr',
#  'institute': 'IPSL',
#  'mip': 'CMIP',
#  'realization': ['r10i1p1f1',
#   'r11i1p1f1',
#   'r12i1p1f1',
#   'r13i1p1f1',
#   'r14i1p1f1',
#   'r15i1p1f1',
#   'r16i1p1f1',
#   'r17i1p1f1',
#   'r18i1p1f1',
#   'r19i1p1f1',
#   'r1i1p1f1',
#   'r20i1p1f1',
#   'r21i1p1f1',
#   'r22i1p1f1',
#   'r23i1p1f1',
#   'r24i1p1f1',
#   'r25i1p1f1',
#   'r26i1p1f1',
#   'r27i1p1f1',
#   'r28i1p1f1',
#   'r29i1p1f1',
#   'r2i1p1f1',
#   'r30i1p1f1',
#   'r31i1p1f1',
#   'r32i1p1f1',
#   'r3i1p1f1',
#   'r4i1p1f1',
#   'r5i1p1f1',
#   'r6i1p1f1',
#   'r7i1p1f1',
#   'r8i1p1f1',
#   'r9i1p1f1']}

# %%
ens_snow = req_snow.explore('ensemble')

# %%
summary(ens_snow)
# Out:
# Keys - values:
# {'domain': [25, 90, -180, 180], 'version': 'latest', 'institute': 'IPSL', 'realization': 'r10i1p1f1', 'period': 2005-2014, 'simulation': '', 'project': 'CMIP6', 'experiment': 'historical', 'grid': 'gr', 'table': 'LImon', 'variable': 'snc', 'mip': 'CMIP', 'model': 'IPSL-CM6A-LR', 'root': '/bdd'}
# -- Ensemble members:
# r10i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r10i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r10i1p1f1_gr_185001-201412.nc
# --
# r11i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r11i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r11i1p1f1_gr_185001-201412.nc
# --
# r12i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r12i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r12i1p1f1_gr_185001-201412.nc
# --
# r13i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r13i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r13i1p1f1_gr_185001-201412.nc
# --
# r14i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r14i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r14i1p1f1_gr_185001-201412.nc
# --
# r15i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r15i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r15i1p1f1_gr_185001-201412.nc
# --
# r16i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r16i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r16i1p1f1_gr_185001-201412.nc
# --
# r17i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r17i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r17i1p1f1_gr_185001-201412.nc
# --
# r18i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r18i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r18i1p1f1_gr_185001-201412.nc
# --
# r19i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r19i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r19i1p1f1_gr_185001-201412.nc
# --
# r1i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r1i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc
# --
# r20i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r20i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r20i1p1f1_gr_185001-201412.nc
# --
# r21i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r21i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r21i1p1f1_gr_185001-201412.nc
# --
# r22i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r22i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r22i1p1f1_gr_185001-201412.nc
# --
# r23i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r23i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r23i1p1f1_gr_185001-201412.nc
# --
# r24i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r24i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r24i1p1f1_gr_185001-201412.nc
# --
# r25i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r25i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r25i1p1f1_gr_185001-201412.nc
# --
# r26i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r26i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r26i1p1f1_gr_185001-201412.nc
# --
# r27i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r27i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r27i1p1f1_gr_185001-201412.nc
# --
# r28i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r28i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r28i1p1f1_gr_185001-201412.nc
# --
# r29i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r29i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r29i1p1f1_gr_185001-201412.nc
# --
# r2i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r2i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r2i1p1f1_gr_185001-201412.nc
# --
# r30i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r30i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r30i1p1f1_gr_185001-201412.nc
# --
# r31i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r31i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r31i1p1f1_gr_185001-201412.nc
# --
# r32i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r32i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r32i1p1f1_gr_185001-201412.nc
# --
# r3i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r3i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r3i1p1f1_gr_185001-201412.nc
# --
# r4i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r4i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r4i1p1f1_gr_185001-201412.nc
# --
# r5i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r5i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r5i1p1f1_gr_185001-201412.nc
# --
# r6i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r6i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r6i1p1f1_gr_185001-201412.nc
# --
# r7i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r7i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r7i1p1f1_gr_185001-201412.nc
# --
# r8i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r8i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r8i1p1f1_gr_185001-201412.nc
# --
# r9i1p1f1
# /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r9i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r9i1p1f1_gr_185001-201412.nc
# --

# %%
ncdump(ens_snow)
# Out:
# netcdf \1 {
# dimensions:
# 	time = UNLIMITED ; // (120 currently)
# 	bnds = 2 ;
# 	lon = 144 ;
# 	lat = 52 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:long_name = "Time axis" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1850-01-01 00:00:00" ;
# 		time:calendar = "gregorian" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float snc(time, lat, lon) ;
# 		snc:standard_name = "surface_snow_area_fraction" ;
# 		snc:long_name = "Snow Area Fraction" ;
# 		snc:units = "%" ;
# 		snc:_FillValue = 1.e+20f ;
# 		snc:missing_value = 1.e+20f ;
# 		snc:online_operation = "average" ;
# 		snc:cell_methods = "area: time: mean" ;
# 		snc:interval_operation = "900 s" ;
# 		snc:interval_write = "1 month" ;
# 		snc:description = "Fraction of each grid cell that is occupied by snow that rests on land portion of cell." ;
# 		snc:history = "none" ;
# 		snc:cell_measures = "area: areacella" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Mon Oct 28 14:53:19 2019: cdo -O -seldate,2005-01-01T00:00:00,2014-12-31T23:59:00 -sellonlatbox,-180,180,25,90 -selname,snc /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r10i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r10i1p1f1_gr_185001-201412.nc /data/mlalande/climafcache/f6a98/68579/d8211/d8318/bcbfa/2641a/297d9/ff2cb/915c1/a8288/fe827/1_62654.nc\nMon Sep  3 17:43:24 2018: ncatted -O -a parent_variant_label,global,m,c,r1i1p1f1 snc_LImon_IPSL-CM6A-LR_historical_r10i1p1f1_gr_185001-201412.nc\nnone" ;
# 		:source = "IPSL-CM6A-LR (2017):  atmos: LMDZ (NPv6, N96; 144 x 143 longitude/latitude; 79 levels; top level 40000 m) land: ORCHIDEE (v2.0, Water/Carbon/Energy mode) ocean: NEMO-OPA (eORCA1.3, tripolar primarily 1deg; 362 x 332 longitude/latitude; 75 levels; top grid cell 0-2 m) ocnBgchem: NEMO-PISCES seaIce: NEMO-LIM3" ;
# 		:institution = "Institut Pierre Simon Laplace, Paris 75252, France" ;
# 		:Conventions = "CF-1.7 CMIP-6.2" ;
# 		:name = "/ccc/work/cont003/gencmip6/p86maf/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2190/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r10i1p1f1_gr_%start_date%-%end_date%" ;
# 		:creation_date = "2018-06-18T08:05:56Z" ;
# 		:tracking_id = "hdl:21.14100/82f75666-ebee-4d25-ae42-72db1213e473" ;
# 		:description = "CMIP6 historical" ;
# 		:title = "IPSL-CM6A-LR model output prepared for CMIP6 / CMIP historical" ;
# 		:activity_id = "CMIP" ;
# 		:contact = "ipsl-cmip6@listes.ipsl.fr" ;
# 		:data_specs_version = "01.00.21" ;
# 		:dr2xml_version = "1.10" ;
# 		:experiment_id = "historical" ;
# 		:experiment = "all-forcing simulation of the recent past" ;
# 		:external_variables = "areacella" ;
# 		:forcing_index = 1 ;
# 		:frequency = "mon" ;
# 		:further_info_url = "https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM6A-LR.historical.none.r10i1p1f1" ;
# 		:grid = "LMDZ grid" ;
# 		:grid_label = "gr" ;
# 		:nominal_resolution = "250 km" ;
# 		:initialization_index = 1 ;
# 		:institution_id = "IPSL" ;
# 		:license = "CMIP6 model data produced by IPSL is licensed under a Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https://cmc.ipsl.fr/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law." ;
# 		:mip_era = "CMIP6" ;
# 		:parent_experiment_id = "piControl" ;
# 		:parent_mip_era = "CMIP6" ;
# 		:parent_activity_id = "CMIP" ;
# 		:parent_source_id = "IPSL-CM6A-LR" ;
# 		:parent_time_units = "days since 1850-01-01 00:00:00" ;
# 		:branch_method = "standard" ;
# 		:branch_time_in_parent = 124183. ;
# 		:branch_time_in_child = 0. ;
# 		:physics_index = 1 ;
# 		:product = "model-output" ;
# 		:realization_index = 10 ;
# 		:realm = "landIce land" ;
# 		:source_id = "IPSL-CM6A-LR" ;
# 		:source_type = "AOGCM BGC" ;
# 		:sub_experiment_id = "none" ;
# 		:sub_experiment = "none" ;
# 		:table_id = "LImon" ;
# 		:variable_id = "snc" ;
# 		:variant_label = "r10i1p1f1" ;
# 		:EXPID = "historical" ;
# 		:CMIP6_CV_version = "cv=6.2.3.5-2-g63b123e" ;
# 		:dr2xml_md5sum = "d6225e658d7de0912fca2a4293dbe2a7" ;
# 		:model_version = "6.1.4" ;
# 		:parent_variant_label = "r1i1p1f1" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "select(ds(\'CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r10i1p1f1%gr%latest\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.12 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/mlalande/climafcache/f6a98/68579/d8211/d8318/bcbfa/2641a/297d9/ff2cb/915c1/a8288/fe827/1.nc
#
# netcdf \0 {
# dimensions:
# 	time = UNLIMITED ; // (120 currently)
# 	bnds = 2 ;
# 	lon = 144 ;
# 	lat = 52 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:long_name = "Time axis" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1850-01-01 00:00:00" ;
# 		time:calendar = "gregorian" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float snc(time, lat, lon) ;
# 		snc:standard_name = "surface_snow_area_fraction" ;
# 		snc:long_name = "Snow Area Fraction" ;
# 		snc:units = "%" ;
# 		snc:_FillValue = 1.e+20f ;
# 		snc:missing_value = 1.e+20f ;
# 		snc:online_operation = "average" ;
# 		snc:cell_methods = "area: time: mean" ;
# 		snc:interval_operation = "900 s" ;
# 		snc:interval_write = "1 month" ;
# 		snc:description = "Fraction of each grid cell that is occupied by snow that rests on land portion of cell." ;
# 		snc:history = "none" ;
# 		snc:cell_measures = "area: areacella" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Mon Oct 28 14:53:22 2019: cdo -O -seldate,2005-01-01T00:00:00,2014-12-31T23:59:00 -sellonlatbox,-180,180,25,90 -selname,snc /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r11i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r11i1p1f1_gr_185001-201412.nc /data/mlalande/climafcache/c50f4/1bfe1/a7534/6c59b/7b6b4/0df57/f64cb/5f4d1/e82dc/db470/bd846/0_62654.nc\nMon Sep  3 18:10:43 2018: ncatted -O -a parent_variant_label,global,m,c,r1i1p1f1 snc_LImon_IPSL-CM6A-LR_historical_r11i1p1f1_gr_185001-201412.nc\nnone" ;
# 		:source = "IPSL-CM6A-LR (2017):  atmos: LMDZ (NPv6, N96; 144 x 143 longitude/latitude; 79 levels; top level 40000 m) land: ORCHIDEE (v2.0, Water/Carbon/Energy mode) ocean: NEMO-OPA (eORCA1.3, tripolar primarily 1deg; 362 x 332 longitude/latitude; 75 levels; top grid cell 0-2 m) ocnBgchem: NEMO-PISCES seaIce: NEMO-LIM3" ;
# 		:institution = "Institut Pierre Simon Laplace, Paris 75252, France" ;
# 		:Conventions = "CF-1.7 CMIP-6.2" ;
# 		:name = "/ccc/work/cont003/gencmip6/p86maf/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2230/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r11i1p1f1_gr_%start_date%-%end_date%" ;
# 		:creation_date = "2018-06-18T08:06:47Z" ;
# 		:tracking_id = "hdl:21.14100/818f94ae-de44-44a2-8d08-2e5bec69abe8" ;
# 		:description = "CMIP6 historical" ;
# 		:title = "IPSL-CM6A-LR model output prepared for CMIP6 / CMIP historical" ;
# 		:activity_id = "CMIP" ;
# 		:contact = "ipsl-cmip6@listes.ipsl.fr" ;
# 		:data_specs_version = "01.00.21" ;
# 		:dr2xml_version = "1.10" ;
# 		:experiment_id = "historical" ;
# 		:experiment = "all-forcing simulation of the recent past" ;
# 		:external_variables = "areacella" ;
# 		:forcing_index = 1 ;
# 		:frequency = "mon" ;
# 		:further_info_url = "https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM6A-LR.historical.none.r11i1p1f1" ;
# 		:grid = "LMDZ grid" ;
# 		:grid_label = "gr" ;
# 		:nominal_resolution = "250 km" ;
# 		:initialization_index = 1 ;
# 		:institution_id = "IPSL" ;
# 		:license = "CMIP6 model data produced by IPSL is licensed under a Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https://cmc.ipsl.fr/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law." ;
# 		:mip_era = "CMIP6" ;
# 		:parent_experiment_id = "piControl" ;
# 		:parent_mip_era = "CMIP6" ;
# 		:parent_activity_id = "CMIP" ;
# 		:parent_source_id = "IPSL-CM6A-LR" ;
# 		:parent_time_units = "days since 1850-01-01 00:00:00" ;
# 		:branch_method = "standard" ;
# 		:branch_time_in_parent = 138792. ;
# 		:branch_time_in_child = 0. ;
# 		:physics_index = 1 ;
# 		:product = "model-output" ;
# 		:realization_index = 11 ;
# 		:realm = "landIce land" ;
# 		:source_id = "IPSL-CM6A-LR" ;
# 		:source_type = "AOGCM BGC" ;
# 		:sub_experiment_id = "none" ;
# 		:sub_experiment = "none" ;
# 		:table_id = "LImon" ;
# 		:variable_id = "snc" ;
# 		:variant_label = "r11i1p1f1" ;
# 		:EXPID = "historical" ;
# 		:CMIP6_CV_version = "cv=6.2.3.5-2-g63b123e" ;
# 		:dr2xml_md5sum = "d6225e658d7de0912fca2a4293dbe2a7" ;
# 		:model_version = "6.1.4" ;
# 		:parent_variant_label = "r1i1p1f1" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "select(ds(\'CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r11i1p1f1%gr%latest\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.12 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/mlalande/climafcache/c50f4/1bfe1/a7534/6c59b/7b6b4/0df57/f64cb/5f4d1/e82dc/db470/bd846/0.nc
# netcdf c {
# dimensions:
# 	time = UNLIMITED ; // (120 currently)
# 	bnds = 2 ;
# 	lon = 144 ;
# 	lat = 52 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:long_name = "Time axis" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1850-01-01 00:00:00" ;
# 		time:calendar = "gregorian" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float snc(time, lat, lon) ;
# 		snc:standard_name = "surface_snow_area_fraction" ;
# 		snc:long_name = "Snow Area Fraction" ;
# 		snc:units = "%" ;
# 		snc:_FillValue = 1.e+20f ;
# 		snc:missing_value = 1.e+20f ;
# 		snc:online_operation = "average" ;
# 		snc:cell_methods = "area: time: mean" ;
# 		snc:interval_operation = "900 s" ;
# 		snc:interval_write = "1 month" ;
# 		snc:description = "Fraction of each grid cell that is occupied by snow that rests on land portion of cell." ;
# 		snc:history = "none" ;
# 		snc:cell_measures = "area: areacella" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Mon Oct 28 14:53:24 2019: cdo -O -seldate,2005-01-01T00:00:00,2014-12-31T23:59:00 -sellonlatbox,-180,180,25,90 -selname,snc /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r12i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r12i1p1f1_gr_185001-201412.nc /data/mlalande/climafcache/5e18b/ea76c/c8e4d/3e2fb/b9ee3/a7d32/59947/8d445/cc05a/062e3/9c983/c_62654.nc\nTue Sep  4 11:10:12 2018: ncatted -O -a parent_variant_label,global,m,c,r1i1p1f1 /ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2270/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r12i1p1f1_gr_185001-201412.nc\nTue Sep  4 11:00:51 2018: ncatted -O -a parent_variant_label,global,m,c,r1i1p1f1 /ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2270/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r12i1p1f1_gr_185001-201412.nc\nnone" ;
# 		:source = "IPSL-CM6A-LR (2017):  atmos: LMDZ (NPv6, N96; 144 x 143 longitude/latitude; 79 levels; top level 40000 m) land: ORCHIDEE (v2.0, Water/Carbon/Energy mode) ocean: NEMO-OPA (eORCA1.3, tripolar primarily 1deg; 362 x 332 longitude/latitude; 75 levels; top grid cell 0-2 m) ocnBgchem: NEMO-PISCES seaIce: NEMO-LIM3" ;
# 		:institution = "Institut Pierre Simon Laplace, Paris 75252, France" ;
# 		:Conventions = "CF-1.7 CMIP-6.2" ;
# 		:name = "/ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2270/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r12i1p1f1_gr_%start_date%-%end_date%" ;
# 		:creation_date = "2018-08-10T18:47:58Z" ;
# 		:tracking_id = "hdl:21.14100/17a70c09-7d05-4782-ac37-04711b3dfd1e" ;
# 		:description = "CMIP6 historical" ;
# 		:title = "IPSL-CM6A-LR model output prepared for CMIP6 / CMIP historical" ;
# 		:activity_id = "CMIP" ;
# 		:contact = "ipsl-cmip6@listes.ipsl.fr" ;
# 		:data_specs_version = "01.00.21" ;
# 		:dr2xml_version = "1.12" ;
# 		:experiment_id = "historical" ;
# 		:experiment = "all-forcing simulation of the recent past" ;
# 		:external_variables = "areacella" ;
# 		:forcing_index = 1 ;
# 		:frequency = "mon" ;
# 		:further_info_url = "https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM6A-LR.historical.none.r12i1p1f1" ;
# 		:grid = "LMDZ grid" ;
# 		:grid_label = "gr" ;
# 		:nominal_resolution = "250 km" ;
# 		:initialization_index = 1 ;
# 		:institution_id = "IPSL" ;
# 		:license = "CMIP6 model data produced by IPSL is licensed under a Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https://cmc.ipsl.fr/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law." ;
# 		:mip_era = "CMIP6" ;
# 		:parent_experiment_id = "piControl" ;
# 		:parent_mip_era = "CMIP6" ;
# 		:parent_activity_id = "CMIP" ;
# 		:parent_source_id = "IPSL-CM6A-LR" ;
# 		:parent_time_units = "days since 1850-01-01 00:00:00" ;
# 		:branch_method = "standard" ;
# 		:branch_time_in_parent = 153402. ;
# 		:branch_time_in_child = 0. ;
# 		:physics_index = 1 ;
# 		:product = "model-output" ;
# 		:realization_index = 12 ;
# 		:realm = "landIce land" ;
# 		:source_id = "IPSL-CM6A-LR" ;
# 		:source_type = "AOGCM BGC" ;
# 		:sub_experiment_id = "none" ;
# 		:sub_experiment = "none" ;
# 		:table_id = "LImon" ;
# 		:variable_id = "snc" ;
# 		:variant_label = "r12i1p1f1" ;
# 		:EXPID = "historical" ;
# 		:CMIP6_CV_version = "cv=6.2.3.5-2-g63b123e" ;
# 		:dr2xml_md5sum = "523ab9c7b70cfe3bc2c825d1e555e1d0" ;
# 		:model_version = "6.1.5" ;
# 		:parent_variant_label = "r1i1p1f1" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "select(ds(\'CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r12i1p1f1%gr%latest\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.12 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/mlalande/climafcache/5e18b/ea76c/c8e4d/3e2fb/b9ee3/a7d32/59947/8d445/cc05a/062e3/9c983/c.nc
#
# netcdf \7 {
# dimensions:
# 	time = UNLIMITED ; // (120 currently)
# 	bnds = 2 ;
# 	lon = 144 ;
# 	lat = 52 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:long_name = "Time axis" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1850-01-01 00:00:00" ;
# 		time:calendar = "gregorian" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float snc(time, lat, lon) ;
# 		snc:standard_name = "surface_snow_area_fraction" ;
# 		snc:long_name = "Snow Area Fraction" ;
# 		snc:units = "%" ;
# 		snc:_FillValue = 1.e+20f ;
# 		snc:missing_value = 1.e+20f ;
# 		snc:online_operation = "average" ;
# 		snc:cell_methods = "area: time: mean" ;
# 		snc:interval_operation = "900 s" ;
# 		snc:interval_write = "1 month" ;
# 		snc:description = "Fraction of each grid cell that is occupied by snow that rests on land portion of cell." ;
# 		snc:history = "none" ;
# 		snc:cell_measures = "area: areacella" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Mon Oct 28 14:53:27 2019: cdo -O -seldate,2005-01-01T00:00:00,2014-12-31T23:59:00 -sellonlatbox,-180,180,25,90 -selname,snc /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r13i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r13i1p1f1_gr_185001-201412.nc /data/mlalande/climafcache/aa221/930ed/65120/a9bf1/9d495/9e758/f5a13/fa2f8/88b64/909aa/2464d/7_62654.nc\nTue Sep  4 11:22:56 2018: ncatted -O -a parent_variant_label,global,m,c,r1i1p1f1 /ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2310/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r13i1p1f1_gr_185001-201412.nc\nnone" ;
# 		:source = "IPSL-CM6A-LR (2017):  atmos: LMDZ (NPv6, N96; 144 x 143 longitude/latitude; 79 levels; top level 40000 m) land: ORCHIDEE (v2.0, Water/Carbon/Energy mode) ocean: NEMO-OPA (eORCA1.3, tripolar primarily 1deg; 362 x 332 longitude/latitude; 75 levels; top grid cell 0-2 m) ocnBgchem: NEMO-PISCES seaIce: NEMO-LIM3" ;
# 		:institution = "Institut Pierre Simon Laplace, Paris 75252, France" ;
# 		:Conventions = "CF-1.7 CMIP-6.2" ;
# 		:name = "/ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2310/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r13i1p1f1_gr_%start_date%-%end_date%" ;
# 		:creation_date = "2018-08-10T18:53:06Z" ;
# 		:tracking_id = "hdl:21.14100/4eec317e-506d-4239-a7fe-61045b369f1d" ;
# 		:description = "CMIP6 historical" ;
# 		:title = "IPSL-CM6A-LR model output prepared for CMIP6 / CMIP historical" ;
# 		:activity_id = "CMIP" ;
# 		:contact = "ipsl-cmip6@listes.ipsl.fr" ;
# 		:data_specs_version = "01.00.21" ;
# 		:dr2xml_version = "1.12" ;
# 		:experiment_id = "historical" ;
# 		:experiment = "all-forcing simulation of the recent past" ;
# 		:external_variables = "areacella" ;
# 		:forcing_index = 1 ;
# 		:frequency = "mon" ;
# 		:further_info_url = "https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM6A-LR.historical.none.r13i1p1f1" ;
# 		:grid = "LMDZ grid" ;
# 		:grid_label = "gr" ;
# 		:nominal_resolution = "250 km" ;
# 		:initialization_index = 1 ;
# 		:institution_id = "IPSL" ;
# 		:license = "CMIP6 model data produced by IPSL is licensed under a Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https://cmc.ipsl.fr/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law." ;
# 		:mip_era = "CMIP6" ;
# 		:parent_experiment_id = "piControl" ;
# 		:parent_mip_era = "CMIP6" ;
# 		:parent_activity_id = "CMIP" ;
# 		:parent_source_id = "IPSL-CM6A-LR" ;
# 		:parent_time_units = "days since 1850-01-01 00:00:00" ;
# 		:branch_method = "standard" ;
# 		:branch_time_in_parent = 168011. ;
# 		:branch_time_in_child = 0. ;
# 		:physics_index = 1 ;
# 		:product = "model-output" ;
# 		:realization_index = 13 ;
# 		:realm = "landIce land" ;
# 		:source_id = "IPSL-CM6A-LR" ;
# 		:source_type = "AOGCM BGC" ;
# 		:sub_experiment_id = "none" ;
# 		:sub_experiment = "none" ;
# 		:table_id = "LImon" ;
# 		:variable_id = "snc" ;
# 		:variant_label = "r13i1p1f1" ;
# 		:EXPID = "historical" ;
# 		:CMIP6_CV_version = "cv=6.2.3.5-2-g63b123e" ;
# 		:dr2xml_md5sum = "523ab9c7b70cfe3bc2c825d1e555e1d0" ;
# 		:model_version = "6.1.5" ;
# 		:parent_variant_label = "r1i1p1f1" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "select(ds(\'CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r13i1p1f1%gr%latest\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.12 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/mlalande/climafcache/aa221/930ed/65120/a9bf1/9d495/9e758/f5a13/fa2f8/88b64/909aa/2464d/7.nc
# netcdf \8 {
# dimensions:
# 	time = UNLIMITED ; // (120 currently)
# 	bnds = 2 ;
# 	lon = 144 ;
# 	lat = 52 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:long_name = "Time axis" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1850-01-01 00:00:00" ;
# 		time:calendar = "gregorian" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float snc(time, lat, lon) ;
# 		snc:standard_name = "surface_snow_area_fraction" ;
# 		snc:long_name = "Snow Area Fraction" ;
# 		snc:units = "%" ;
# 		snc:_FillValue = 1.e+20f ;
# 		snc:missing_value = 1.e+20f ;
# 		snc:online_operation = "average" ;
# 		snc:cell_methods = "area: time: mean" ;
# 		snc:interval_operation = "900 s" ;
# 		snc:interval_write = "1 month" ;
# 		snc:description = "Fraction of each grid cell that is occupied by snow that rests on land portion of cell." ;
# 		snc:history = "none" ;
# 		snc:cell_measures = "area: areacella" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Mon Oct 28 14:53:30 2019: cdo -O -seldate,2005-01-01T00:00:00,2014-12-31T23:59:00 -sellonlatbox,-180,180,25,90 -selname,snc /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r14i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r14i1p1f1_gr_185001-201412.nc /data/mlalande/climafcache/be0a2/98235/62cbe/cbbe6/d5c9e/03974/9f1f4/cd0b8/d79f5/ff741/f32d6/8_62654.nc\nTue Sep  4 14:18:24 2018: ncatted -O -a parent_variant_label,global,m,c,r1i1p1f1 /ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.1970/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r14i1p1f1_gr_185001-201412.nc\nnone" ;
# 		:source = "IPSL-CM6A-LR (2017):  atmos: LMDZ (NPv6, N96; 144 x 143 longitude/latitude; 79 levels; top level 40000 m) land: ORCHIDEE (v2.0, Water/Carbon/Energy mode) ocean: NEMO-OPA (eORCA1.3, tripolar primarily 1deg; 362 x 332 longitude/latitude; 75 levels; top grid cell 0-2 m) ocnBgchem: NEMO-PISCES seaIce: NEMO-LIM3" ;
# 		:institution = "Institut Pierre Simon Laplace, Paris 75252, France" ;
# 		:Conventions = "CF-1.7 CMIP-6.2" ;
# 		:name = "/ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.1970/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r14i1p1f1_gr_%start_date%-%end_date%" ;
# 		:creation_date = "2018-08-08T19:33:40Z" ;
# 		:tracking_id = "hdl:21.14100/942d10a9-63e4-41d4-b2db-7fbc7c99cbd2" ;
# 		:description = "CMIP6 historical" ;
# 		:title = "IPSL-CM6A-LR model output prepared for CMIP6 / CMIP historical" ;
# 		:activity_id = "CMIP" ;
# 		:contact = "ipsl-cmip6@listes.ipsl.fr" ;
# 		:data_specs_version = "01.00.21" ;
# 		:dr2xml_version = "1.12" ;
# 		:experiment_id = "historical" ;
# 		:experiment = "all-forcing simulation of the recent past" ;
# 		:external_variables = "areacella" ;
# 		:forcing_index = 1 ;
# 		:frequency = "mon" ;
# 		:further_info_url = "https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM6A-LR.historical.none.r14i1p1f1" ;
# 		:grid = "LMDZ grid" ;
# 		:grid_label = "gr" ;
# 		:nominal_resolution = "250 km" ;
# 		:initialization_index = 1 ;
# 		:institution_id = "IPSL" ;
# 		:license = "CMIP6 model data produced by IPSL is licensed under a Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https://cmc.ipsl.fr/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law." ;
# 		:mip_era = "CMIP6" ;
# 		:parent_experiment_id = "piControl" ;
# 		:parent_mip_era = "CMIP6" ;
# 		:parent_activity_id = "CMIP" ;
# 		:parent_source_id = "IPSL-CM6A-LR" ;
# 		:parent_time_units = "days since 1850-01-01 00:00:00" ;
# 		:branch_method = "standard" ;
# 		:branch_time_in_parent = 43829. ;
# 		:branch_time_in_child = 0. ;
# 		:physics_index = 1 ;
# 		:product = "model-output" ;
# 		:realization_index = 14 ;
# 		:realm = "landIce land" ;
# 		:source_id = "IPSL-CM6A-LR" ;
# 		:source_type = "AOGCM BGC" ;
# 		:sub_experiment_id = "none" ;
# 		:sub_experiment = "none" ;
# 		:table_id = "LImon" ;
# 		:variable_id = "snc" ;
# 		:variant_label = "r14i1p1f1" ;
# 		:EXPID = "historical" ;
# 		:CMIP6_CV_version = "cv=6.2.3.5-2-g63b123e" ;
# 		:dr2xml_md5sum = "523ab9c7b70cfe3bc2c825d1e555e1d0" ;
# 		:model_version = "6.1.5" ;
# 		:parent_variant_label = "r1i1p1f1" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "select(ds(\'CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r14i1p1f1%gr%latest\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.12 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/mlalande/climafcache/be0a2/98235/62cbe/cbbe6/d5c9e/03974/9f1f4/cd0b8/d79f5/ff741/f32d6/8.nc
#
# netcdf \0 {
# dimensions:
# 	time = UNLIMITED ; // (120 currently)
# 	bnds = 2 ;
# 	lon = 144 ;
# 	lat = 52 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:long_name = "Time axis" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1850-01-01 00:00:00" ;
# 		time:calendar = "gregorian" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float snc(time, lat, lon) ;
# 		snc:standard_name = "surface_snow_area_fraction" ;
# 		snc:long_name = "Snow Area Fraction" ;
# 		snc:units = "%" ;
# 		snc:_FillValue = 1.e+20f ;
# 		snc:missing_value = 1.e+20f ;
# 		snc:online_operation = "average" ;
# 		snc:cell_methods = "area: time: mean" ;
# 		snc:interval_operation = "900 s" ;
# 		snc:interval_write = "1 month" ;
# 		snc:description = "Fraction of each grid cell that is occupied by snow that rests on land portion of cell." ;
# 		snc:history = "none" ;
# 		snc:cell_measures = "area: areacella" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Mon Oct 28 14:53:32 2019: cdo -O -seldate,2005-01-01T00:00:00,2014-12-31T23:59:00 -sellonlatbox,-180,180,25,90 -selname,snc /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r15i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r15i1p1f1_gr_185001-201412.nc /data/mlalande/climafcache/8f7ac/8ca82/7ab17/ccc27/681b3/d42a9/51fa3/80282/cc3b8/774de/1ba9e/0_62654.nc\nTue Sep  4 14:32:53 2018: ncatted -O -a parent_variant_label,global,m,c,r1i1p1f1 /ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2010/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r15i1p1f1_gr_185001-201412.nc\nnone" ;
# 		:source = "IPSL-CM6A-LR (2017):  atmos: LMDZ (NPv6, N96; 144 x 143 longitude/latitude; 79 levels; top level 40000 m) land: ORCHIDEE (v2.0, Water/Carbon/Energy mode) ocean: NEMO-OPA (eORCA1.3, tripolar primarily 1deg; 362 x 332 longitude/latitude; 75 levels; top grid cell 0-2 m) ocnBgchem: NEMO-PISCES seaIce: NEMO-LIM3" ;
# 		:institution = "Institut Pierre Simon Laplace, Paris 75252, France" ;
# 		:Conventions = "CF-1.7 CMIP-6.2" ;
# 		:name = "/ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2010/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r15i1p1f1_gr_%start_date%-%end_date%" ;
# 		:creation_date = "2018-08-10T18:02:55Z" ;
# 		:tracking_id = "hdl:21.14100/cf36e0f2-3162-416f-9f4f-5096aff9dd63" ;
# 		:description = "CMIP6 historical" ;
# 		:title = "IPSL-CM6A-LR model output prepared for CMIP6 / CMIP historical" ;
# 		:activity_id = "CMIP" ;
# 		:contact = "ipsl-cmip6@listes.ipsl.fr" ;
# 		:data_specs_version = "01.00.21" ;
# 		:dr2xml_version = "1.12" ;
# 		:experiment_id = "historical" ;
# 		:experiment = "all-forcing simulation of the recent past" ;
# 		:external_variables = "areacella" ;
# 		:forcing_index = 1 ;
# 		:frequency = "mon" ;
# 		:further_info_url = "https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM6A-LR.historical.none.r15i1p1f1" ;
# 		:grid = "LMDZ grid" ;
# 		:grid_label = "gr" ;
# 		:nominal_resolution = "250 km" ;
# 		:initialization_index = 1 ;
# 		:institution_id = "IPSL" ;
# 		:license = "CMIP6 model data produced by IPSL is licensed under a Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https://cmc.ipsl.fr/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law." ;
# 		:mip_era = "CMIP6" ;
# 		:parent_experiment_id = "piControl" ;
# 		:parent_mip_era = "CMIP6" ;
# 		:parent_activity_id = "CMIP" ;
# 		:parent_source_id = "IPSL-CM6A-LR" ;
# 		:parent_time_units = "days since 1850-01-01 00:00:00" ;
# 		:branch_method = "standard" ;
# 		:branch_time_in_parent = 58439. ;
# 		:branch_time_in_child = 0. ;
# 		:physics_index = 1 ;
# 		:product = "model-output" ;
# 		:realization_index = 15 ;
# 		:realm = "landIce land" ;
# 		:source_id = "IPSL-CM6A-LR" ;
# 		:source_type = "AOGCM BGC" ;
# 		:sub_experiment_id = "none" ;
# 		:sub_experiment = "none" ;
# 		:table_id = "LImon" ;
# 		:variable_id = "snc" ;
# 		:variant_label = "r15i1p1f1" ;
# 		:EXPID = "historical" ;
# 		:CMIP6_CV_version = "cv=6.2.3.5-2-g63b123e" ;
# 		:dr2xml_md5sum = "523ab9c7b70cfe3bc2c825d1e555e1d0" ;
# 		:model_version = "6.1.5" ;
# 		:parent_variant_label = "r1i1p1f1" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "select(ds(\'CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r15i1p1f1%gr%latest\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.12 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/mlalande/climafcache/8f7ac/8ca82/7ab17/ccc27/681b3/d42a9/51fa3/80282/cc3b8/774de/1ba9e/0.nc
# netcdf \6 {
# dimensions:
# 	time = UNLIMITED ; // (120 currently)
# 	bnds = 2 ;
# 	lon = 144 ;
# 	lat = 52 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:long_name = "Time axis" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1850-01-01 00:00:00" ;
# 		time:calendar = "gregorian" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float snc(time, lat, lon) ;
# 		snc:standard_name = "surface_snow_area_fraction" ;
# 		snc:long_name = "Snow Area Fraction" ;
# 		snc:units = "%" ;
# 		snc:_FillValue = 1.e+20f ;
# 		snc:missing_value = 1.e+20f ;
# 		snc:online_operation = "average" ;
# 		snc:cell_methods = "area: time: mean" ;
# 		snc:interval_operation = "900 s" ;
# 		snc:interval_write = "1 month" ;
# 		snc:description = "Fraction of each grid cell that is occupied by snow that rests on land portion of cell." ;
# 		snc:history = "none" ;
# 		snc:cell_measures = "area: areacella" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Mon Oct 28 14:53:35 2019: cdo -O -seldate,2005-01-01T00:00:00,2014-12-31T23:59:00 -sellonlatbox,-180,180,25,90 -selname,snc /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r16i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r16i1p1f1_gr_185001-201412.nc /data/mlalande/climafcache/c52a3/7dea6/8ba9f/230b9/afb74/4f576/0be8b/cb6d7/5129e/0ff8a/be2de/6_62654.nc\nTue Sep  4 15:32:26 2018: ncatted -O -a parent_variant_label,global,m,c,r1i1p1f1 /ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2050/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r16i1p1f1_gr_185001-201412.nc\nnone" ;
# 		:source = "IPSL-CM6A-LR (2017):  atmos: LMDZ (NPv6, N96; 144 x 143 longitude/latitude; 79 levels; top level 40000 m) land: ORCHIDEE (v2.0, Water/Carbon/Energy mode) ocean: NEMO-OPA (eORCA1.3, tripolar primarily 1deg; 362 x 332 longitude/latitude; 75 levels; top grid cell 0-2 m) ocnBgchem: NEMO-PISCES seaIce: NEMO-LIM3" ;
# 		:institution = "Institut Pierre Simon Laplace, Paris 75252, France" ;
# 		:Conventions = "CF-1.7 CMIP-6.2" ;
# 		:name = "/ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2050/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r16i1p1f1_gr_%start_date%-%end_date%" ;
# 		:creation_date = "2018-08-10T18:03:46Z" ;
# 		:tracking_id = "hdl:21.14100/4fc63aa6-741e-4423-b33a-c05a7789df33" ;
# 		:description = "CMIP6 historical" ;
# 		:title = "IPSL-CM6A-LR model output prepared for CMIP6 / CMIP historical" ;
# 		:activity_id = "CMIP" ;
# 		:contact = "ipsl-cmip6@listes.ipsl.fr" ;
# 		:data_specs_version = "01.00.21" ;
# 		:dr2xml_version = "1.12" ;
# 		:experiment_id = "historical" ;
# 		:experiment = "all-forcing simulation of the recent past" ;
# 		:external_variables = "areacella" ;
# 		:forcing_index = 1 ;
# 		:frequency = "mon" ;
# 		:further_info_url = "https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM6A-LR.historical.none.r16i1p1f1" ;
# 		:grid = "LMDZ grid" ;
# 		:grid_label = "gr" ;
# 		:nominal_resolution = "250 km" ;
# 		:initialization_index = 1 ;
# 		:institution_id = "IPSL" ;
# 		:license = "CMIP6 model data produced by IPSL is licensed under a Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https://cmc.ipsl.fr/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law." ;
# 		:mip_era = "CMIP6" ;
# 		:parent_experiment_id = "piControl" ;
# 		:parent_mip_era = "CMIP6" ;
# 		:parent_activity_id = "CMIP" ;
# 		:parent_source_id = "IPSL-CM6A-LR" ;
# 		:parent_time_units = "days since 1850-01-01 00:00:00" ;
# 		:branch_method = "standard" ;
# 		:branch_time_in_parent = 73049. ;
# 		:branch_time_in_child = 0. ;
# 		:physics_index = 1 ;
# 		:product = "model-output" ;
# 		:realization_index = 16 ;
# 		:realm = "landIce land" ;
# 		:source_id = "IPSL-CM6A-LR" ;
# 		:source_type = "AOGCM BGC" ;
# 		:sub_experiment_id = "none" ;
# 		:sub_experiment = "none" ;
# 		:table_id = "LImon" ;
# 		:variable_id = "snc" ;
# 		:variant_label = "r16i1p1f1" ;
# 		:EXPID = "historical" ;
# 		:CMIP6_CV_version = "cv=6.2.3.5-2-g63b123e" ;
# 		:dr2xml_md5sum = "523ab9c7b70cfe3bc2c825d1e555e1d0" ;
# 		:model_version = "6.1.5" ;
# 		:parent_variant_label = "r1i1p1f1" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "select(ds(\'CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r16i1p1f1%gr%latest\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.12 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/mlalande/climafcache/c52a3/7dea6/8ba9f/230b9/afb74/4f576/0be8b/cb6d7/5129e/0ff8a/be2de/6.nc
#
# netcdf d {
# dimensions:
# 	time = UNLIMITED ; // (120 currently)
# 	bnds = 2 ;
# 	lon = 144 ;
# 	lat = 52 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:long_name = "Time axis" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1850-01-01 00:00:00" ;
# 		time:calendar = "gregorian" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float snc(time, lat, lon) ;
# 		snc:standard_name = "surface_snow_area_fraction" ;
# 		snc:long_name = "Snow Area Fraction" ;
# 		snc:units = "%" ;
# 		snc:_FillValue = 1.e+20f ;
# 		snc:missing_value = 1.e+20f ;
# 		snc:online_operation = "average" ;
# 		snc:cell_methods = "area: time: mean" ;
# 		snc:interval_operation = "900 s" ;
# 		snc:interval_write = "1 month" ;
# 		snc:description = "Fraction of each grid cell that is occupied by snow that rests on land portion of cell." ;
# 		snc:history = "none" ;
# 		snc:cell_measures = "area: areacella" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Mon Oct 28 14:53:37 2019: cdo -O -seldate,2005-01-01T00:00:00,2014-12-31T23:59:00 -sellonlatbox,-180,180,25,90 -selname,snc /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r17i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r17i1p1f1_gr_185001-201412.nc /data/mlalande/climafcache/7f476/81a3d/0510f/35bf9/a75bb/eef51/b43a0/6e55a/c2464/d9aa1/1b828/d_62654.nc\nTue Sep  4 16:27:14 2018: ncatted -O -a parent_variant_label,global,m,c,r1i1p1f1 /ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2090/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r17i1p1f1_gr_185001-201412.nc\nnone" ;
# 		:source = "IPSL-CM6A-LR (2017):  atmos: LMDZ (NPv6, N96; 144 x 143 longitude/latitude; 79 levels; top level 40000 m) land: ORCHIDEE (v2.0, Water/Carbon/Energy mode) ocean: NEMO-OPA (eORCA1.3, tripolar primarily 1deg; 362 x 332 longitude/latitude; 75 levels; top grid cell 0-2 m) ocnBgchem: NEMO-PISCES seaIce: NEMO-LIM3" ;
# 		:institution = "Institut Pierre Simon Laplace, Paris 75252, France" ;
# 		:Conventions = "CF-1.7 CMIP-6.2" ;
# 		:name = "/ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2090/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r17i1p1f1_gr_%start_date%-%end_date%" ;
# 		:creation_date = "2018-08-10T18:03:59Z" ;
# 		:tracking_id = "hdl:21.14100/f33a1645-2f43-41c8-a95c-75e771ca0eff" ;
# 		:description = "CMIP6 historical" ;
# 		:title = "IPSL-CM6A-LR model output prepared for CMIP6 / CMIP historical" ;
# 		:activity_id = "CMIP" ;
# 		:contact = "ipsl-cmip6@listes.ipsl.fr" ;
# 		:data_specs_version = "01.00.21" ;
# 		:dr2xml_version = "1.12" ;
# 		:experiment_id = "historical" ;
# 		:experiment = "all-forcing simulation of the recent past" ;
# 		:external_variables = "areacella" ;
# 		:forcing_index = 1 ;
# 		:frequency = "mon" ;
# 		:further_info_url = "https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM6A-LR.historical.none.r17i1p1f1" ;
# 		:grid = "LMDZ grid" ;
# 		:grid_label = "gr" ;
# 		:nominal_resolution = "250 km" ;
# 		:initialization_index = 1 ;
# 		:institution_id = "IPSL" ;
# 		:license = "CMIP6 model data produced by IPSL is licensed under a Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https://cmc.ipsl.fr/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law." ;
# 		:mip_era = "CMIP6" ;
# 		:parent_experiment_id = "piControl" ;
# 		:parent_mip_era = "CMIP6" ;
# 		:parent_activity_id = "CMIP" ;
# 		:parent_source_id = "IPSL-CM6A-LR" ;
# 		:parent_time_units = "days since 1850-01-01 00:00:00" ;
# 		:branch_method = "standard" ;
# 		:branch_time_in_parent = 87659. ;
# 		:branch_time_in_child = 0. ;
# 		:physics_index = 1 ;
# 		:product = "model-output" ;
# 		:realization_index = 17 ;
# 		:realm = "landIce land" ;
# 		:source_id = "IPSL-CM6A-LR" ;
# 		:source_type = "AOGCM BGC" ;
# 		:sub_experiment_id = "none" ;
# 		:sub_experiment = "none" ;
# 		:table_id = "LImon" ;
# 		:variable_id = "snc" ;
# 		:variant_label = "r17i1p1f1" ;
# 		:EXPID = "historical" ;
# 		:CMIP6_CV_version = "cv=6.2.3.5-2-g63b123e" ;
# 		:dr2xml_md5sum = "523ab9c7b70cfe3bc2c825d1e555e1d0" ;
# 		:model_version = "6.1.5" ;
# 		:parent_variant_label = "r1i1p1f1" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "select(ds(\'CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r17i1p1f1%gr%latest\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.12 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/mlalande/climafcache/7f476/81a3d/0510f/35bf9/a75bb/eef51/b43a0/6e55a/c2464/d9aa1/1b828/d.nc
# netcdf \0 {
# dimensions:
# 	time = UNLIMITED ; // (120 currently)
# 	bnds = 2 ;
# 	lon = 144 ;
# 	lat = 52 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:long_name = "Time axis" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1850-01-01 00:00:00" ;
# 		time:calendar = "gregorian" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float snc(time, lat, lon) ;
# 		snc:standard_name = "surface_snow_area_fraction" ;
# 		snc:long_name = "Snow Area Fraction" ;
# 		snc:units = "%" ;
# 		snc:_FillValue = 1.e+20f ;
# 		snc:missing_value = 1.e+20f ;
# 		snc:online_operation = "average" ;
# 		snc:cell_methods = "area: time: mean" ;
# 		snc:interval_operation = "900 s" ;
# 		snc:interval_write = "1 month" ;
# 		snc:description = "Fraction of each grid cell that is occupied by snow that rests on land portion of cell." ;
# 		snc:history = "none" ;
# 		snc:cell_measures = "area: areacella" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Mon Oct 28 14:53:40 2019: cdo -O -seldate,2005-01-01T00:00:00,2014-12-31T23:59:00 -sellonlatbox,-180,180,25,90 -selname,snc /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r18i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r18i1p1f1_gr_185001-201412.nc /data/mlalande/climafcache/c53aa/209ca/e1c09/8a9b2/0ba36/9a5f9/7d91e/ce070/07056/c08db/3157d/0_62654.nc\nTue Sep  4 16:27:44 2018: ncatted -O -a parent_variant_label,global,m,c,r1i1p1f1 /ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2130/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r18i1p1f1_gr_185001-201412.nc\nnone" ;
# 		:source = "IPSL-CM6A-LR (2017):  atmos: LMDZ (NPv6, N96; 144 x 143 longitude/latitude; 79 levels; top level 40000 m) land: ORCHIDEE (v2.0, Water/Carbon/Energy mode) ocean: NEMO-OPA (eORCA1.3, tripolar primarily 1deg; 362 x 332 longitude/latitude; 75 levels; top grid cell 0-2 m) ocnBgchem: NEMO-PISCES seaIce: NEMO-LIM3" ;
# 		:institution = "Institut Pierre Simon Laplace, Paris 75252, France" ;
# 		:Conventions = "CF-1.7 CMIP-6.2" ;
# 		:name = "/ccc/work/cont003/gencmip6/p86denv/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2130/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r18i1p1f1_gr_%start_date%-%end_date%" ;
# 		:creation_date = "2018-08-10T18:04:29Z" ;
# 		:tracking_id = "hdl:21.14100/095b5a5f-afc1-4ee7-b5d9-466e815be4c6" ;
# 		:description = "CMIP6 historical" ;
# 		:title = "IPSL-CM6A-LR model output prepared for CMIP6 / CMIP historical" ;
# 		:activity_id = "CMIP" ;
# 		:contact = "ipsl-cmip6@listes.ipsl.fr" ;
# 		:data_specs_version = "01.00.21" ;
# 		:dr2xml_version = "1.12" ;
# 		:experiment_id = "historical" ;
# 		:experiment = "all-forcing simulation of the recent past" ;
# 		:external_variables = "areacella" ;
# 		:forcing_index = 1 ;
# 		:frequency = "mon" ;
# 		:further_info_url = "https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM6A-LR.historical.none.r18i1p1f1" ;
# 		:grid = "LMDZ grid" ;
# 		:grid_label = "gr" ;
# 		:nominal_resolution = "250 km" ;
# 		:initialization_index = 1 ;
# 		:institution_id = "IPSL" ;
# 		:license = "CMIP6 model data produced by IPSL is licensed under a Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https://cmc.ipsl.fr/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law." ;
# 		:mip_era = "CMIP6" ;
# 		:parent_experiment_id = "piControl" ;
# ...
# 		:parent_experiment_id = "piControl" ;
# 		:parent_mip_era = "CMIP6" ;
# 		:parent_activity_id = "CMIP" ;
# 		:parent_source_id = "IPSL-CM6A-LR" ;
# 		:parent_time_units = "days since 1850-01-01 00:00:00" ;
# 		:branch_method = "standard" ;
# 		:branch_time_in_parent = 80354. ;
# 		:branch_time_in_child = 0. ;
# 		:physics_index = 1 ;
# 		:product = "model-output" ;
# 		:realization_index = 7 ;
# 		:realm = "landIce land" ;
# 		:source_id = "IPSL-CM6A-LR" ;
# 		:source_type = "AOGCM BGC" ;
# 		:sub_experiment_id = "none" ;
# 		:sub_experiment = "none" ;
# 		:table_id = "LImon" ;
# 		:variable_id = "snc" ;
# 		:variant_label = "r7i1p1f1" ;
# 		:EXPID = "historical" ;
# 		:CMIP6_CV_version = "cv=6.2.3.5-2-g63b123e" ;
# 		:dr2xml_md5sum = "f91de4d48022fecbbf24061748ee64ec" ;
# 		:model_version = "6.1.3" ;
# 		:parent_variant_label = "r1i1p1f1" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "select(ds(\'CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r7i1p1f1%gr%latest\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.12 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/mlalande/climafcache/163a0/00c91/7a485/6b4b4/3a135/7c75d/65b89/0adec/2c40f/1549d/639cd/d.nc
# netcdf \8 {
# dimensions:
# 	time = UNLIMITED ; // (120 currently)
# 	bnds = 2 ;
# 	lon = 144 ;
# 	lat = 52 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:long_name = "Time axis" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1850-01-01 00:00:00" ;
# 		time:calendar = "gregorian" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float snc(time, lat, lon) ;
# 		snc:standard_name = "surface_snow_area_fraction" ;
# 		snc:long_name = "Snow Area Fraction" ;
# 		snc:units = "%" ;
# 		snc:_FillValue = 1.e+20f ;
# 		snc:missing_value = 1.e+20f ;
# 		snc:online_operation = "average" ;
# 		snc:cell_methods = "area: time: mean" ;
# 		snc:interval_operation = "900 s" ;
# 		snc:interval_write = "1 month" ;
# 		snc:description = "Fraction of each grid cell that is occupied by snow that rests on land portion of cell." ;
# 		snc:history = "none" ;
# 		snc:cell_measures = "area: areacella" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Mon Oct 28 14:54:36 2019: cdo -O -seldate,2005-01-01T00:00:00,2014-12-31T23:59:00 -sellonlatbox,-180,180,25,90 -selname,snc /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r8i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r8i1p1f1_gr_185001-201412.nc /data/mlalande/climafcache/84565/570fc/890ba/595e9/42bcb/dfe37/3950c/f9887/7e389/d33fa/faf87/8_62654.nc\nMon Sep  3 16:42:47 2018: ncatted -O -a parent_variant_label,global,m,c,r1i1p1f1 snc_LImon_IPSL-CM6A-LR_historical_r8i1p1f1_gr_185001-201412.nc\nnone" ;
# 		:source = "IPSL-CM6A-LR (2017):  atmos: LMDZ (NPv6, N96; 144 x 143 longitude/latitude; 79 levels; top level 40000 m) land: ORCHIDEE (v2.0, Water/Carbon/Energy mode) ocean: NEMO-OPA (eORCA1.3, tripolar primarily 1deg; 362 x 332 longitude/latitude; 75 levels; top grid cell 0-2 m) ocnBgchem: NEMO-PISCES seaIce: NEMO-LIM3" ;
# 		:institution = "Institut Pierre Simon Laplace, Paris 75252, France" ;
# 		:Conventions = "CF-1.7 CMIP-6.2" ;
# 		:name = "/ccc/work/cont003/gencmip6/p86mign/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2110/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r8i1p1f1_gr_%start_date%-%end_date%" ;
# 		:creation_date = "2018-06-08T12:58:26Z" ;
# 		:tracking_id = "hdl:21.14100/787f8379-2c11-47f8-901f-609af8e6d902" ;
# 		:description = "CMIP6 historical" ;
# 		:title = "IPSL-CM6A-LR model output prepared for CMIP6 / CMIP historical" ;
# 		:activity_id = "CMIP" ;
# 		:contact = "ipsl-cmip6@listes.ipsl.fr" ;
# 		:data_specs_version = "01.00.21" ;
# 		:dr2xml_version = "1.8" ;
# 		:experiment_id = "historical" ;
# 		:experiment = "all-forcing simulation of the recent past" ;
# 		:external_variables = "areacella" ;
# 		:forcing_index = 1 ;
# 		:frequency = "mon" ;
# 		:further_info_url = "https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM6A-LR.historical.none.r8i1p1f1" ;
# 		:grid = "LMDZ grid" ;
# 		:grid_label = "gr" ;
# 		:nominal_resolution = "250 km" ;
# 		:initialization_index = 1 ;
# 		:institution_id = "IPSL" ;
# 		:license = "CMIP6 model data produced by IPSL is licensed under a Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https://cmc.ipsl.fr/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law." ;
# 		:mip_era = "CMIP6" ;
# 		:parent_experiment_id = "piControl" ;
# 		:parent_mip_era = "CMIP6" ;
# 		:parent_activity_id = "CMIP" ;
# 		:parent_source_id = "IPSL-CM6A-LR" ;
# 		:parent_time_units = "days since 1850-01-01 00:00:00" ;
# 		:branch_method = "standard" ;
# 		:branch_time_in_parent = 94963. ;
# 		:branch_time_in_child = 0. ;
# 		:physics_index = 1 ;
# 		:product = "model-output" ;
# 		:realization_index = 8 ;
# 		:realm = "landIce land" ;
# 		:source_id = "IPSL-CM6A-LR" ;
# 		:source_type = "AOGCM BGC" ;
# 		:sub_experiment_id = "none" ;
# 		:sub_experiment = "none" ;
# 		:table_id = "LImon" ;
# 		:variable_id = "snc" ;
# 		:variant_label = "r8i1p1f1" ;
# 		:EXPID = "historical" ;
# 		:CMIP6_CV_version = "cv=6.2.3.5-2-g63b123e" ;
# 		:dr2xml_md5sum = "f91de4d48022fecbbf24061748ee64ec" ;
# 		:model_version = "6.1.3" ;
# 		:parent_variant_label = "r1i1p1f1" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "select(ds(\'CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r8i1p1f1%gr%latest\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.12 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/mlalande/climafcache/84565/570fc/890ba/595e9/42bcb/dfe37/3950c/f9887/7e389/d33fa/faf87/8.nc
#
# netcdf \0 {
# dimensions:
# 	time = UNLIMITED ; // (120 currently)
# 	bnds = 2 ;
# 	lon = 144 ;
# 	lat = 52 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:long_name = "Time axis" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1850-01-01 00:00:00" ;
# 		time:calendar = "gregorian" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	float lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	float lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float snc(time, lat, lon) ;
# 		snc:standard_name = "surface_snow_area_fraction" ;
# 		snc:long_name = "Snow Area Fraction" ;
# 		snc:units = "%" ;
# 		snc:_FillValue = 1.e+20f ;
# 		snc:missing_value = 1.e+20f ;
# 		snc:online_operation = "average" ;
# 		snc:cell_methods = "area: time: mean" ;
# 		snc:interval_operation = "900 s" ;
# 		snc:interval_write = "1 month" ;
# 		snc:description = "Fraction of each grid cell that is occupied by snow that rests on land portion of cell." ;
# 		snc:history = "none" ;
# 		snc:cell_measures = "area: areacella" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Mon Oct 28 14:54:39 2019: cdo -O -seldate,2005-01-01T00:00:00,2014-12-31T23:59:00 -sellonlatbox,-180,180,25,90 -selname,snc /bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r9i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r9i1p1f1_gr_185001-201412.nc /data/mlalande/climafcache/64b27/62a4c/9d568/b2eae/486a5/56658/00a97/952b8/d1cf1/6f926/37a24/0_62654.nc\nMon Sep  3 16:51:22 2018: ncatted -O -a parent_variant_label,global,m,c,r1i1p1f1 snc_LImon_IPSL-CM6A-LR_historical_r9i1p1f1_gr_185001-201412.nc\nnone" ;
# 		:source = "IPSL-CM6A-LR (2017):  atmos: LMDZ (NPv6, N96; 144 x 143 longitude/latitude; 79 levels; top level 40000 m) land: ORCHIDEE (v2.0, Water/Carbon/Energy mode) ocean: NEMO-OPA (eORCA1.3, tripolar primarily 1deg; 362 x 332 longitude/latitude; 75 levels; top grid cell 0-2 m) ocnBgchem: NEMO-PISCES seaIce: NEMO-LIM3" ;
# 		:institution = "Institut Pierre Simon Laplace, Paris 75252, France" ;
# 		:Conventions = "CF-1.7 CMIP-6.2" ;
# 		:name = "/ccc/work/cont003/gencmip6/p86maf/IGCM_OUT/IPSLCM6/PROD/historical/CM61-LR-hist-03.2150/CMIP6/SRF/snc_LImon_IPSL-CM6A-LR_historical_r9i1p1f1_gr_%start_date%-%end_date%" ;
# 		:creation_date = "2018-06-15T17:54:57Z" ;
# 		:tracking_id = "hdl:21.14100/bcb79e08-89ca-43bd-991e-1f741a27b6b2" ;
# 		:description = "CMIP6 historical" ;
# 		:title = "IPSL-CM6A-LR model output prepared for CMIP6 / CMIP historical" ;
# 		:activity_id = "CMIP" ;
# 		:contact = "ipsl-cmip6@listes.ipsl.fr" ;
# 		:data_specs_version = "01.00.21" ;
# 		:dr2xml_version = "1.10" ;
# 		:experiment_id = "historical" ;
# 		:experiment = "all-forcing simulation of the recent past" ;
# 		:external_variables = "areacella" ;
# 		:forcing_index = 1 ;
# 		:frequency = "mon" ;
# 		:further_info_url = "https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM6A-LR.historical.none.r9i1p1f1" ;
# 		:grid = "LMDZ grid" ;
# 		:grid_label = "gr" ;
# 		:nominal_resolution = "250 km" ;
# 		:initialization_index = 1 ;
# 		:institution_id = "IPSL" ;
# 		:license = "CMIP6 model data produced by IPSL is licensed under a Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https://cmc.ipsl.fr/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law." ;
# 		:mip_era = "CMIP6" ;
# 		:parent_experiment_id = "piControl" ;
# 		:parent_mip_era = "CMIP6" ;
# 		:parent_activity_id = "CMIP" ;
# 		:parent_source_id = "IPSL-CM6A-LR" ;
# 		:parent_time_units = "days since 1850-01-01 00:00:00" ;
# 		:branch_method = "standard" ;
# 		:branch_time_in_parent = 109573. ;
# 		:branch_time_in_child = 0. ;
# 		:physics_index = 1 ;
# 		:product = "model-output" ;
# 		:realization_index = 9 ;
# 		:realm = "landIce land" ;
# 		:source_id = "IPSL-CM6A-LR" ;
# 		:source_type = "AOGCM BGC" ;
# 		:sub_experiment_id = "none" ;
# 		:sub_experiment = "none" ;
# 		:table_id = "LImon" ;
# 		:variable_id = "snc" ;
# 		:variant_label = "r9i1p1f1" ;
# 		:EXPID = "historical" ;
# 		:CMIP6_CV_version = "cv=6.2.3.5-2-g63b123e" ;
# 		:dr2xml_md5sum = "d6225e658d7de0912fca2a4293dbe2a7" ;
# 		:model_version = "6.1.4" ;
# 		:parent_variant_label = "r1i1p1f1" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "select(ds(\'CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r9i1p1f1%gr%latest\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.12 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/mlalande/climafcache/64b27/62a4c/9d568/b2eae/486a5/56658/00a97/952b8/d1cf1/6f926/37a24/0.nc
# cens({'r10i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r10i1p1f1%gr%latest')),'r11i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r11i1p1f1%gr%latest')),'r12i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r12i1p1f1%gr%latest')),'r13i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r13i1p1f1%gr%latest')),'r14i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r14i1p1f1%gr%latest')),'r15i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r15i1p1f1%gr%latest')),'r16i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r16i1p1f1%gr%latest')),'r17i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r17i1p1f1%gr%latest')),'r18i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r18i1p1f1%gr%latest')),'r19i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r19i1p1f1%gr%latest')),'r1i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r1i1p1f1%gr%latest')),'r20i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r20i1p1f1%gr%latest')),'r21i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r21i1p1f1%gr%latest')),'r22i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r22i1p1f1%gr%latest')),'r23i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r23i1p1f1%gr%latest')),'r24i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r24i1p1f1%gr%latest')),'r25i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r25i1p1f1%gr%latest')),'r26i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r26i1p1f1%gr%latest')),'r27i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r27i1p1f1%gr%latest')),'r28i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r28i1p1f1%gr%latest')),'r29i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r29i1p1f1%gr%latest')),'r2i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r2i1p1f1%gr%latest')),'r30i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r30i1p1f1%gr%latest')),'r31i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r31i1p1f1%gr%latest')),'r32i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r32i1p1f1%gr%latest')),'r3i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r3i1p1f1%gr%latest')),'r4i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r4i1p1f1%gr%latest')),'r5i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r5i1p1f1%gr%latest')),'r6i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r6i1p1f1%gr%latest')),'r7i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25, 90, -180, 180]%/bdd%IPSL-CM6A-LR%IPSL%CMIP%LImon%historical%r7i1p1f1%gr%latest')),'r8i1p1f1':ncdump(ds('CMIP6%%snc%2005-2014%[25,  ...

# %%
# Define a CDO function
cscript("ensavg","cdo ensavg ${mmin} ${out}")
# Out:
# CliMAF operator : ensavg

# %%
# Check the data producing a map with CLIMAF
MAM_ens_cmip6 = clim_average(ens_snow,'MAM')
ens_avg_snow=ensavg(MAM_ens_cmip6)
reduced_map=llbox(ens_avg_snow, lonmin=-180, lonmax=180, latmin=20, latmax=90)

# %%
pp = dict(focus='land', contours=1,title='MAM snow area fraction')
myplot = plot(reduced_map,**pp)
iplot(myplot)

# %%
cerr()

# %%
# Check the type of climaf data
type(req_snow), type(ens_snow), type(reduced_map), type(plot(reduced_map,**pp))
# Out:
# (instance, climaf.classes.cens, instance, instance)

# %%
# We import standard python libraries, in particular because we are not using only CLIMAF
import numpy as np
import numpy.ma as ma
import matplotlib.pyplot as plt
from scipy import stats
#Activate plots visualization on ipython
# %matplotlib inline

# %%
# Monthly mean
monthly_snow=ccdo(ens_snow,operator='monmean')

# %%
# Extract March and April
march_snow=ccdo(monthly_snow,operator='selmon,3')
april_snow=ccdo(monthly_snow,operator='selmon,4')

# %%
# Spatial average
march_snow_bis=space_average(march_snow)
april_snow_bis=space_average(april_snow)

# %%
# climaf.classes.cens --> dictionary
march_snow_ter=cMA(march_snow_bis)
april_snow_ter=cMA(april_snow_bis)

# %%
type(req_snow), type(march_snow_bis), type(march_snow_ter)
# Out:
# (instance, climaf.classes.cens, dict)

# %%
# Initializing march-april arrays
march_april_snow=np.full([len(march_snow_ter),march_snow_ter["r1i1p1f1"].shape[0]], np.nan)
march_april_snow_trend=np.full([len(march_snow_ter)],np.nan)
march_april_snow_pvalue=np.full([len(march_snow_ter)],np.nan)
march_april_snow_intercept=np.full([len(march_snow_ter)],np.nan)
march_april_snow_ideal=np.full([len(march_snow_ter),march_snow_ter["r1i1p1f1"].shape[0]], np.nan)
nb_years=march_snow_ter["r1i1p1f1"].shape[0]

# %%
march_april_snow.shape, march_april_snow_trend.shape, nb_years
# Out:
# ((31, 10), (31,), 10)

# %%
# Compute hemispheric trends and linear regressions
for num_memb in range(len(march_snow_ter)):
    memb="r"+str(num_memb+1)+"i1p1f1"
    #print(memb)
    tmp=np.stack((march_snow_ter[memb][:,0,0],april_snow_ter[memb][:,0,0]),axis=1)
    march_april_snow[num_memb,:]=np.average(tmp,axis=1)
    tmp_stat=stats.linregress(range(march_april_snow.shape[1]),march_april_snow[num_memb,:])
    march_april_snow_trend[num_memb]=tmp_stat.slope
    march_april_snow_pvalue[num_memb]=tmp_stat.pvalue
    march_april_snow_intercept[num_memb]=tmp_stat.intercept
    march_april_snow_ideal[num_memb,:]=march_april_snow_intercept[num_memb]+\
    march_april_snow_trend[num_memb]*np.arange(nb_years)

# %%
for num_memb in range(len(march_snow_ter)):
    plt.plot(march_april_snow[num_memb,:])
    plt.plot(march_april_snow_ideal[num_memb,:], 'r', label=num_memb)
plt.plot(np.mean(march_april_snow_ideal,axis=0), color='black', linewidth=2)

# %%
# We load the data from the piControl run:
data_piControl = np.load('save_snow_piControl_10y_trend.npz')
mu_piControl=data_piControl['mu']
std_piControl=data_piControl['std']

# %%
mu_piControl, std_piControl
# Out:
# (array(0.0004719), array(0.16638042))

# %%
# We load the NCEP observational datasets
import xarray as xr
file='/home/mmenegoz/travaux_martin/CMIP6-Analysis-CLIMERI-2018119/ref/NH_march_april_snc_mon.ncarcfsr_1979-2016_r360x180.nc'
with xr.open_dataset(file) as ds:
    snc_obs = ds['snowc']
    lat_obs = ds['lat']
    lon_obs = ds['lon']

# %%
type(snc_obs), snc_obs.shape, lat_obs.shape, lon_obs.shape
# Out:
# (xarray.core.dataarray.DataArray, (38, 65, 360), (65,), (360,))

# %%
weights=np.cos(np.deg2rad(lat_obs))
snc_obs_masked=ma.masked_where(snc_obs == 9999, snc_obs)
zonal_mean=snc_obs_masked.mean(axis=2)
ave_snc_obs = np.average(zonal_mean, axis=1, weights=weights)

# %%
first_year_ncar=1979
first_index=first_year-first_year_ncar
second_index=first_index+last_year-first_year+1
obs_period=ave_snc_obs[first_index:second_index]
obs_period.shape
# Out:
# (10,)

# %%
obs_stat=stats.linregress(range(obs_period.shape[0]),obs_period[:])
march_april_snow_trend_obs=obs_stat.slope
march_april_snow_trend_obs
# Out:
# 0.049259907452895525

# %%
# We load NOAA observational dataset:
file='/home/mmenegoz/travaux_martin/CMIP6-Analysis-CLIMERI-2018119/ref/NH_march_april_snowc.mon.noaaV2c_185101_201412_2.0x1.75'
with xr.open_dataset(file) as ds:
    snc_noaa = ds['snowc']
    lat_noaa = ds['lat']
    lon_noaa = ds['lon']

# %%
first_year_noaa=1851
first_index_noaa=first_year-first_year_noaa
second_index_noaa=first_index_noaa+last_year-first_year+1
1995-1851, 2014-1851, 165-144
first_index_noaa, second_index_noaa
# Out:
# (154, 164)

# %%
1851+144
# Out:
# 1995

# %%
plt.imshow(snc_noaa[0,:,:]), plt.colorbar()
# Out:
# (<matplotlib.image.AxesImage at 0x2aba152f0ad0>,
#  <matplotlib.colorbar.Colorbar at 0x2aba15327c90>)

# %%
weights_noaa=np.cos(np.deg2rad(lat_noaa))
masked_noaa = ma.masked_array(snc_noaa, np.isnan(snc_noaa))
zonal_mean_noaa=masked_noaa.mean(axis=2)
ave_snc_noaa=np.average(zonal_mean_noaa, axis=1, weights=weights_noaa)
noaa_period=ave_snc_noaa[first_index_noaa:second_index_noaa]

# %%
# Rutgers University data
file='/home/mmenegoz/travaux_martin/CMIP6-Analysis-CLIMERI-2018119/ref/Timeseries_snc_rutgers_NH_MarApr_1967-2015.dat'
rutgers = np.loadtxt(file, comments="#", delimiter=" ", unpack=False)

# %%
first_year_rutgers=1967
first_index_rutgers=first_year-first_year_rutgers
second_index_rutgers=first_index_rutgers+last_year-first_year+1
first_index_rutgers, second_index_rutgers
# Out:
# (38, 48)

# %%
rutgers_period=rutgers[first_index_rutgers:second_index_rutgers]

# %%
plt.plot(noaa_period, label='NOAA'), plt.plot(obs_period, label='NCEP'); plt.plot(rutgers_period,label='RUTGERS')
plt.legend(loc='lower left')
plt.savefig(period_extract+'_snow_observations_trend'+figure_type)
plt.savefig(period_extract+'_snow_observations_trend'+figure_type2)

# %%
rutgers_stat=stats.linregress(range(rutgers_period.shape[0]),rutgers_period[:])
march_april_snow_trend_rutgers=rutgers_stat.slope
march_april_snow_trend_rutgers
# Out:
# 0.048315248706124046

# %%
noaa_stat=stats.linregress(range(noaa_period.shape[0]),noaa_period[:])
march_april_snow_trend_noaa=noaa_stat.slope
march_april_snow_trend_noaa
# Out:
# 0.0009098819916163183

# %%
march_april_snow_trend
# Out:
# array([-0.12181988,  0.11683273, -0.07388969, -0.01887681, -0.19284645,
#         0.18243693,  0.07411938, -0.21226437, -0.08907529, -0.0306661 ,
#         0.23129735, -0.09966546,  0.07431865, -0.13357197, -0.03860661,
#        -0.03968719, -0.32821741, -0.03633034, -0.14649085, -0.33328629,
#        -0.06701866, -0.17464387, -0.07222521,  0.12805518, -0.17219046,
#        -0.50627118, -0.296579  , -0.10240825,  0.09953604,  0.24692612,
#        -0.45023106])

# %%
# Plot the histogram
num_memb=len(march_snow_ter)
xmin, xmax=(-0.6,0.6)
plt.hist(march_april_snow_trend, density=False, range=(xmin,xmax), label='IPSL ensemble')
# Plot the PDF from the piControl:
x = np.linspace(xmin, xmax, 100)
p = stats.norm.pdf(x, mu_piControl, std_piControl)
plt.plot(x, p*5, 'k', linewidth=2, label="piControl") # *11/6 to be justified
plt.axvline(x=march_april_snow_trend_obs, color='r', linestyle='-', linewidth=2, label='NCEP')
plt.axvline(x=march_april_snow_trend_noaa, color='g', linestyle='dashed', linewidth=2, label='NOAA')
plt.axvline(x=march_april_snow_trend_rutgers, color='purple', linestyle='dashed', linewidth=2, label='RUTGERS')
plt.legend(loc='upper right')
title = period_extract+" trend of snow cover in NH (%)"
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title(title, fontsize=20)
plt.savefig(period_extract+'_snow_histo_trend'+figure_type)
plt.savefig(period_extract+'_snow_histo_trend'+figure_type2)

# %%
np.savez('save_snow_trend.npz', march_april_snow=march_april_snow, \
         march_april_snow_trend=march_april_snow_trend,\
         march_april_snow_ideal=march_april_snow_ideal)

# %%
march_april_snow.shape, march_april_snow_trend.shape
# Out:
# ((31, 10), (31,))

# %%
march_snow_2D=cMA(march_snow)
april_snow_2D=cMA(april_snow)

# %%
# %run -i 'standard_operators.py'

# %%
march_snow_2D['r10i1p1f1'].shape[1:3], len(march_snow_2D)
lat_length=march_snow_2D["r1i1p1f1"].shape[1]
lon_length=march_snow_2D["r1i1p1f1"].shape[2]
ens_length=len(march_snow_2D)
nb_years=march_snow_2D["r1i1p1f1"].shape[0]
ens_length,lon_length,lat_length,march_snow_2D["r1i1p1f1"].shape
# Out:
# (31, 144, 52, (10, 52, 144))

# %%
march_snow_2D['r10i1p1f1'].shape, np.ma.getmask(march_snow_2D['r1i1p1f1']).shape
# Out:
# ((10, 52, 144), (10, 52, 144))

# %%
#Spatial trends, initializing march-april arrays
march_april_snow_2D_trend=np.full([ens_length,lat_length,lon_length],np.nan)
march_april_snow_2D_pvalue=np.full([ens_length,lat_length,lon_length],np.nan)

# %%
march_snow_2D["r1i1p1f1"].shape,march_april_snow_2D_pvalue.shape
# Out:
# ((10, 52, 144), (31, 52, 144))

# %%
# Compute the spatial trend
for num_memb in range(len(march_snow_ter)):
    memb="r"+str(num_memb+1)+"i1p1f1"
    print(memb)
    tmp=np.stack((march_snow_2D[memb],april_snow_2D[memb]),axis=0)
    march_april_snow_memb=np.average(tmp,axis=0)
    for ji in range(lat_length):
        for jj in range(lon_length):
            tmp_stat=stats.linregress(range(march_april_snow_memb.shape[0]),march_april_snow_memb[:,ji,jj])
            march_april_snow_2D_trend[num_memb,ji,jj]=tmp_stat.slope
            march_april_snow_2D_pvalue[num_memb,ji,jj]=tmp_stat.pvalue
# Out:
# r1i1p1f1
# r2i1p1f1
# r3i1p1f1
# r4i1p1f1
# r5i1p1f1
# r6i1p1f1
# r7i1p1f1
# r8i1p1f1
# r9i1p1f1
# r10i1p1f1
# r11i1p1f1
# r12i1p1f1
# r13i1p1f1
# r14i1p1f1
# r15i1p1f1
# r16i1p1f1
# r17i1p1f1
# r18i1p1f1
# r19i1p1f1
# r20i1p1f1
# r21i1p1f1
# r22i1p1f1
# r23i1p1f1
# r24i1p1f1
# r25i1p1f1
# r26i1p1f1
# r27i1p1f1
# r28i1p1f1
# r29i1p1f1
# r30i1p1f1
# r31i1p1f1

# %%
# Mean trend for all the members
march_april_snow_2D_trend_ensmean=np.mean(march_april_snow_2D_trend,axis=0)

# %%
# We get the lat/lon to produce the plots with basemap
import xarray as xr
file='/bdd/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r1i1p1f1/LImon/snc/gr/latest/snc_LImon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc'
with xr.open_dataset(file) as ds:
    latitudes = ds['lat']
    longitudes = ds['lon']

# %%
march_april_snow_2D_trend_ensmean.shape, longitudes.shape, latitudes.shape
# Out:
# ((52, 144), (144,), (143,))

# %%
# Compute the member mean (climatology)
snow_spatial_mean_r1=np.mean(march_snow_2D['r1i1p1f1'],axis=0)
sum_members=np.ma.array(np.zeros(snow_spatial_mean_r1.shape),\
                        mask=np.ma.getmask(snow_spatial_mean_r1))
for num_memb in range(len(march_snow_ter)):
    memb="r"+str(num_memb+1)+"i1p1f1"
    print(memb)
    tmp=np.stack((march_snow_2D[memb],april_snow_2D[memb]),axis=0)
    march_april_snow_memb=np.average(tmp,axis=0)
    sum_members=np.mean(march_april_snow_memb,axis=0)+sum_members
clim_march_snow_2D=sum_members/len(march_snow_ter)
# Out:
# r1i1p1f1
# r2i1p1f1
# r3i1p1f1
# r4i1p1f1
# r5i1p1f1
# r6i1p1f1
# r7i1p1f1
# r8i1p1f1
# r9i1p1f1
# r10i1p1f1
# r11i1p1f1
# r12i1p1f1
# r13i1p1f1
# r14i1p1f1
# r15i1p1f1
# r16i1p1f1
# r17i1p1f1
# r18i1p1f1
# r19i1p1f1
# r20i1p1f1
# r21i1p1f1
# r22i1p1f1
# r23i1p1f1
# r24i1p1f1
# r25i1p1f1
# r26i1p1f1
# r27i1p1f1
# r28i1p1f1
# r29i1p1f1
# r30i1p1f1
# r31i1p1f1

# %%
np.savez('save_snow_trend_2D.npz', march_april_snow_2D_pvalue=march_april_snow_2D_pvalue,\
         march_april_snow_2D_trend=march_april_snow_2D_trend,\
         latitudes=latitudes, longitudes=longitudes)

# %%
type(march_april_snow_2D_trend), march_april_snow_2D_trend.shape
# Out:
# (numpy.ndarray, (31, 52, 144))

# %%
# We use only the NH data
latitudes_NH=latitudes[latitudes>25]

# %%
# Save the data in a netcdf file
MA_snow_trend = xr.Dataset({'march_april_snow_2D_trend_ensmean':(['y','x'],np.array(march_april_snow_2D_trend_ensmean)),\
                           'lon':(['x'],np.array(longitudes)),\
                           'lat':(['y'],np.array(latitudes_NH))})
MA_snow_trend.to_netcdf('MA_snow_trend_'+period_extract+'.nc')

# %%
from   mpl_toolkits.basemap import Basemap
import mpl_toolkits.basemap as     bm

# %%
# We exclude the trend where there is no snow and where the snow data is masked:
snow_spatial_mean_r1=np.mean(march_snow_2D['r1i1p1f1'],axis=0)
march_april_snow_2D_trend_ensmean[(snow_spatial_mean_r1<=1)]=np.nan
march_april_snow_2D_trend_ensmean[np.ma.getmask(snow_spatial_mean_r1)==True]=np.nan

# %%
# Variables to map
var1=clim_march_snow_2D
var2=march_april_snow_2D_trend_ensmean
# We shift the longitudes
lon,lon = bm.shiftgrid(180., longitudes,  np.array(longitudes), start=False)
# Expand to a 2-D grid
lon, lat = np.meshgrid(lon, np.array(latitudes_NH))

# %%
m = Basemap(resolution='l',projection='cyl',\
            llcrnrlon=-180,llcrnrlat=25.,urcrnrlon=180,urcrnrlat=90,\
            lat_0=30.,lon_0=0.)
x, y = m(lon, lat)

# %%
plt.figure(figsize=(20,10))
m.drawcoastlines(linewidth = 0.5)
clevs = np.arange(-100, 100, 10)
cf = m.contourf(x, y, var1, latlon = False,\
                cmap = plt.cm.bwr_r, extend = "both", levels = clevs)
cbar = m.colorbar(cf, location = 'bottom',size=0.5)
cbar.set_label("%",fontsize=20)
cbar.ax.set_xticklabels(cbar.ax.get_xticklabels(), fontsize=20)
plt.title(period_extract+' snow cover fraction, mean of the 31 members')
#plt.savefig(period_extract+'snow_trend.ps')
plt.show()

# %%
plt.figure(figsize=(15,15))
m.drawcoastlines(linewidth = 0.5)
clevs = np.arange(-5, 5, 1)
clev_clim_10=10
clev_clim_50=50
cf = m.contourf(x, y, 10*var2, latlon = False,\
                cmap = plt.cm.bwr_r, extend = "both", levels = clevs)
cbar = m.colorbar(cf, location = 'bottom',size=0.25)
cf = m.contour(x,y,var1,linewidths=2,colors='black',levels=clev_clim_10,label='10% level')
cf = m.contour(x,y,var1,linewidths=2,colors='blue',levels=clev_clim_50,linestyle='dotted',label='50% level')
cbar.set_label("% per decade",fontsize=20)
cbar.ax.set_xticklabels(cbar.ax.get_xticklabels(), fontsize=20)
plt.title('IPSL-CM6 '+period_extract+' trend of snow cover fraction in March-April',fontsize=20)
#plt.legend(loc='upper right')
plt.savefig(period_extract+'_snow_trend'+figure_type)
plt.savefig(period_extract+'_snow_trend'+figure_type2)
# Out:
# /prodigfs/ipslfs/dods/jservon/miniconda/envs/cesmep_env/lib/python2.7/site-packages/matplotlib/contour.py:1004: UserWarning: The following kwargs were not used by contour: 'label'
#   s)
# /prodigfs/ipslfs/dods/jservon/miniconda/envs/cesmep_env/lib/python2.7/site-packages/matplotlib/contour.py:1004: UserWarning: The following kwargs were not used by contour: 'linestyle', 'label'
#   s)
